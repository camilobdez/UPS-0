# %% [markdown]
# ## Create, store and slice events

# %%
import dv_processing as dv

# Initialize an empty store
store = dv.EventStore()

# Get the current timestamp
timestamp = dv.now()

# Add some events into the event store
# This allocates and inserts events at the back, the function arguments are:
# timestamp, x, y, polarity
store.push_back(timestamp, 0, 0, True)
store.push_back(timestamp + 1000, 1, 1, False)
store.push_back(timestamp + 2000, 2, 2, False)
store.push_back(timestamp + 3000, 3, 3, True)

# Perform time-based slicing of event store, the output event store "sliced" will contain
# the second and third events from above. The end timestamp (second argument) is 2001, since start
# timestamp (first argument) is inclusive and timestamp is exclusive, so 1 is added.
sliced = store.sliceTime(timestamp + 1000, timestamp + 2001)

# This should print two events
for ev in store:
    print(f"Sliced event [{ev.timestamp()}, {ev.x()}, {ev.y()}, {ev.polarity()}]")

print("---------------------------------------------")

for ev in sliced:
    print(f"Sliced event [{ev.timestamp()}, {ev.x()}, {ev.y()}, {ev.polarity()}]")
# Out:
# Sliced event [1756835056449278, 0, 0, True]
# Sliced event [1756835056450278, 1, 1, False]
# Sliced event [1756835056451278, 2, 2, False]
# Sliced event [1756835056452278, 3, 3, True]
# ---------------------------------------------
# Sliced event [1756835056450278, 1, 1, False]
# Sliced event [1756835056451278, 2, 2, False]

# %% [markdown]
# ### Slicing by time

# %%
import dv_processing as dv
import cv2
import numpy as np
from datetime import timedelta

# Generate synthetic events
store = dv.data.generate.uniformEventsWithinTimeRange(10000, timedelta(milliseconds=10), (100, 100), 10)

# Loop over each event
for i, ev in enumerate(store):
    # Create a blank black image
    image = np.zeros((180, 240, 3), dtype=np.uint8)

    # Draw the event
    x, y, polarity = ev.x(), ev.y(), ev.polarity()
    color = (255, 255, 255) if polarity else (0, 0, 255)
    cv2.circle(image, (x, y), 2, color, -1)

    # Show the image
    cv2.imshow("Event", image)
    cv2.waitKey(500)  # show each image for 500 ms

cv2.destroyAllWindows()

# Get all events with timestamp above 12500, it will be 13000 and up
eventsAfterTimestamp = store.sliceTime(12500)

# Print the timestamp ranges
print(f"1. {eventsAfterTimestamp}")

# Slice event within time range [12000; 16000); the end time is exclusive
eventsInRange = store.sliceTime(12000, 16000)

# Print the timestamp ranges; It will print that range is [12000; 15000] since end time is exclusive and
# event at timestamp 16000 is not going to be included.
print(f"2. {eventsInRange}")
# Out:
# 1. EventStore containing 7 events within 6000µs duration; time range within [13000; 19000]
# 2. EventStore containing 4 events within 3000µs duration; time range within [12000; 15000]

# %% [markdown]
# ### Slicing by number of events

# %%
import dv_processing as dv
from datetime import timedelta

# Generate 10 events with time range [10000; 20000]
store = dv.data.generate.uniformEventsWithinTimeRange(10000, timedelta(milliseconds=10), (100, 100), 10)

# Get all events beyond and including index 5
events_after_index = store.slice(5)
print(f"1. {events_after_index}")

# Get 3 events starting with index 2  
events_in_range = store.slice(2, 3)
print(f"2. {events_in_range}")

# Use sliceBack to retrieve event from the end; this call will retrieve last 3 events
last_events = store.sliceBack(3)
print(f"3. {last_events}")
# Out:
# 1. EventStore containing 5 events within 4000µs duration; time range within [15000; 19000]
# 2. EventStore containing 3 events within 2000µs duration; time range within [12000; 14000]
# 3. EventStore containing 3 events within 2000µs duration; time range within [17000; 19000]

# %% [markdown]
# ### Combining multiple EventStores

# %%
import dv_processing as dv
from datetime import timedelta

# Generate 10 events with timestamps in range [10000; 20000]
store1 = dv.data.generate.uniformEventsWithinTimeRange(10000, timedelta(milliseconds=10), (100, 100), 10)

# Generate second event store with 10 events with timestamps in range [20000; 29000] to the second store
store2 = dv.data.generate.uniformEventsWithinTimeRange(20000, timedelta(milliseconds=10), (100, 100), 10)

# Final event store which will contain all events
final_store = dv.EventStore()

# Add the events into the final store; this operation is shallow, so no data copies
# are performed, but the underlying data has shared ownership between all stores
final_store.add(store1)
final_store.add(store2)

# Print specific information on what we contain in the final event store
print(f"{final_store}")
# Out:
# EventStore containing 20 events within 19000µs duration; time range within [10000; 29000]

# %% [markdown]
# ## Event stream

# %% [markdown]
# ### Event Batch

# %%
import time

import dv_processing as dv

# Open any camera
capture = dv.io.camera.open()

# Run the loop while camera is still connected
while capture.isRunning():
    # Read batch of events
    events = capture.getNextEventBatch()

    # The method does not wait for data arrive, it returns immediately with
    # latest available data or if no data is available, returns a `None`
    if events is not None:
        # Print received packet time range
        print(events)
        #print(events[0].x())
        
    else:
        # No data has arrived yet, short sleep to reduce CPU load
        time.sleep(0.001)
# Out:
# EventStore containing 41 events within 9733µs duration; time range within [1757014899888594; 1757014899898327]
# EventStore containing 39 events within 9882µs duration; time range within [1757014899898673; 1757014899908555]
# EventStore containing 45 events within 9504µs duration; time range within [1757014899908755; 1757014899918259]
# EventStore containing 36 events within 9648µs duration; time range within [1757014899918701; 1757014899928349]
# EventStore containing 42 events within 9989µs duration; time range within [1757014899928584; 1757014899938573]
# EventStore containing 43 events within 9245µs duration; time range within [1757014899939043; 1757014899948288]
# EventStore containing 39 events within 9864µs duration; time range within [1757014899948607; 1757014899958471]
# EventStore containing 47 events within 9619µs duration; time range within [1757014899958865; 1757014899968484]
# EventStore containing 42 events within 9692µs duration; time range within [1757014899968875; 1757014899978567]
# EventStore containing 24 events within 9228µs duration; time range within [1757014899979213; 1757014899988441]
# EventStore containing 40 events within 9346µs duration; time range within [1757014899989189; 1757014899998535]
# EventStore containing 55 events within 9535µs duration; time range within [1757014899999010; 1757014900008545]
# EventStore containing 51 events within 9740µs duration; time range within [1757014900008819; 1757014900018559]
# EventStore containing 53 events within 8829µs duration; time range within [1757014900019010; 1757014900027839]
# EventStore containing 48 events within 9665µs duration; time range within [1757014900028854; 1757014900038519]
# EventStore containing 48 events within 9418µs duration; time range within [1757014900039033; 1757014900048451]
# EventStore containing 60 events within 9708µs duration; time range within [1757014900048811; 1757014900058519]
# EventStore containing 35 events within 9520µs duration; time range within [1757014900058713; 1757014900068233]
# EventStore containing 46 events within 9846µs duration; time range within [1757014900068634; 1757014900078480]
# EventStore containing 52 events within 9816µs duration; time range within [1757014900078604; 1757014900088420]
# EventStore containing 44 events within 9258µs duration; time range within [1757014900089285; 1757014900098543]
# EventStore containing 36 events within 9555µs duration; time range within [1757014900098916; 1757014900108471]
# EventStore containing 38 events within 9666µs duration; time range within [1757014900108815; 1757014900118481]
# EventStore containing 51 events within 9616µs duration; time range within [1757014900118776; 1757014900128392]
# EventStore containing 56 events within 9884µs duration; time range within [1757014900128663; 1757014900138547]
# EventStore containing 41 events within 9293µs duration; time range within [1757014900138727; 1757014900148020]
# EventStore containing 42 events within 9892µs duration; time range within [1757014900148652; 1757014900158544]
# EventStore containing 74 events within 9815µs duration; time range within [1757014900158719; 1757014900168534]
# EventStore containing 35 events within 9925µs duration; time range within [1757014900168641; 1757014900178566]
# EventStore containing 37 events within 8972µs duration; time range within [1757014900179273; 1757014900188245]
# EventStore containing 44 events within 9826µs duration; time range within [1757014900188705; 1757014900198531]
# EventStore containing 44 events within 9282µs duration; time range within [1757014900198840; 1757014900208122]
# EventStore containing 45 events within 9647µs duration; time range within [1757014900208665; 1757014900218312]
# EventStore containing 35 events within 9646µs duration; time range within [1757014900218860; 1757014900228506]
# EventStore containing 61 events within 9778µs duration; time range within [1757014900228673; 1757014900238451]
# EventStore containing 58 events within 9578µs duration; time range within [1757014900239001; 1757014900248579]
# EventStore containing 49 events within 8963µs duration; time range within [1757014900248582; 1757014900257545]
# EventStore containing 44 events within 9824µs duration; time range within [1757014900258738; 1757014900268562]
# EventStore containing 63 events within 9843µs duration; time range within [1757014900268693; 1757014900278536]
# EventStore containing 55 events within 9570µs duration; time range within [1757014900278853; 1757014900288423]
# EventStore containing 40 events within 9775µs duration; time range within [1757014900288728; 1757014900298503]
# EventStore containing 56 events within 9729µs duration; time range within [1757014900298743; 1757014900308472]
# EventStore containing 51 events within 9619µs duration; time range within [1757014900308747; 1757014900318366]
# EventStore containing 66 events within 9852µs duration; time range within [1757014900318601; 1757014900328453]
# EventStore containing 35 events within 9714µs duration; time range within [1757014900328596; 1757014900338310]
# EventStore containing 56 events within 9559µs duration; time range within [1757014900338829; 1757014900348388]
# EventStore containing 70 events within 9889µs duration; time range within [1757014900348590; 1757014900358479]
# EventStore containing 51 events within 9686µs duration; time range within [1757014900358781; 1757014900368467]
# EventStore containing 40 events within 9551µs duration; time range within [1757014900368927; 1757014900378478]
# EventStore containing 44 events within 9782µs duration; time range within [1757014900378665; 1757014900388447]
# EventStore containing 80 events within 9778µs duration; time range within [1757014900388701; 1757014900398479]
# EventStore containing 51 events within 8997µs duration; time range within [1757014900398695; 1757014900407692]
# EventStore containing 47 events within 9918µs duration; time range within [1757014900408599; 1757014900418517]
# EventStore containing 40 events within 9368µs duration; time range within [1757014900418896; 1757014900428264]
# EventStore containing 67 events within 9647µs duration; time range within [1757014900428659; 1757014900438306]
# EventStore containing 48 events within 9658µs duration; time range within [1757014900438694; 1757014900448352]
# EventStore containing 36 events within 8763µs duration; time range within [1757014900448956; 1757014900457719]
# EventStore containing 49 events within 9645µs duration; time range within [1757014900458816; 1757014900468461]
# EventStore containing 62 events within 9597µs duration; time range within [1757014900468775; 1757014900478372]
# EventStore containing 51 events within 9634µs duration; time range within [1757014900478905; 1757014900488539]
# EventStore containing 48 events within 9809µs duration; time range within [1757014900488739; 1757014900498548]
# EventStore containing 67 events within 9828µs duration; time range within [1757014900498658; 1757014900508486]
# EventStore containing 50 events within 9652µs duration; time range within [1757014900508693; 1757014900518345]
# EventStore containing 38 events within 8274µs duration; time range within [1757014900518644; 1757014900526918]
# EventStore containing 50 events within 9072µs duration; time range within [1757014900529316; 1757014900538388]
# EventStore containing 78 events within 9714µs duration; time range within [1757014900538838; 1757014900548552]
# EventStore containing 68 events within 9804µs duration; time range within [1757014900548653; 1757014900558457]
# EventStore containing 42 events within 9937µs duration; time range within [1757014900558595; 1757014900568532]
# EventStore containing 36 events within 9048µs duration; time range within [1757014900568720; 1757014900577768]
# EventStore containing 75 events within 9680µs duration; time range within [1757014900578856; 1757014900588536]
# EventStore containing 46 events within 9304µs duration; time range within [1757014900588597; 1757014900597901]
# EventStore containing 42 events within 9802µs duration; time range within [1757014900598647; 1757014900608449]
# EventStore containing 47 events within 9836µs duration; time range within [1757014900608633; 1757014900618469]
# EventStore containing 72 events within 9757µs duration; time range within [1757014900618743; 1757014900628500]
# EventStore containing 34 events within 9458µs duration; time range within [1757014900628643; 1757014900638101]
# EventStore containing 37 events within 9445µs duration; time range within [1757014900639133; 1757014900648578]
# EventStore containing 51 events within 9635µs duration; time range within [1757014900648592; 1757014900658227]
# EventStore containing 54 events within 9672µs duration; time range within [1757014900658820; 1757014900668492]
# EventStore containing 61 events within 9569µs duration; time range within [1757014900668960; 1757014900678529]
# EventStore containing 45 events within 9436µs duration; time range within [1757014900678960; 1757014900688396]
# EventStore containing 55 events within 9763µs duration; time range within [1757014900688645; 1757014900698408]
# EventStore containing 55 events within 9662µs duration; time range within [1757014900698614; 1757014900708276]
# EventStore containing 47 events within 9294µs duration; time range within [1757014900708696; 1757014900717990]
# EventStore containing 48 events within 9730µs duration; time range within [1757014900718599; 1757014900728329]
# EventStore containing 73 events within 9940µs duration; time range within [1757014900728589; 1757014900738529]
# EventStore containing 91 events within 9825µs duration; time range within [1757014900738690; 1757014900748515]
# EventStore containing 43 events within 9745µs duration; time range within [1757014900748705; 1757014900758450]
# EventStore containing 54 events within 9747µs duration; time range within [1757014900758742; 1757014900768489]
# EventStore containing 65 events within 9346µs duration; time range within [1757014900768959; 1757014900778305]
# EventStore containing 47 events within 9960µs duration; time range within [1757014900778604; 1757014900788564]
# EventStore containing 35 events within 9216µs duration; time range within [1757014900789153; 1757014900798369]
# EventStore containing 40 events within 9938µs duration; time range within [1757014900798585; 1757014900808523]
# EventStore containing 68 events within 9734µs duration; time range within [1757014900808732; 1757014900818466]
# EventStore containing 69 events within 9662µs duration; time range within [1757014900818784; 1757014900828446]
# EventStore containing 43 events within 9481µs duration; time range within [1757014900828619; 1757014900838100]
# EventStore containing 39 events within 9805µs duration; time range within [1757014900838695; 1757014900848500]
# EventStore containing 80 events within 9739µs duration; time range within [1757014900848820; 1757014900858559]
# EventStore containing 52 events within 9488µs duration; time range within [1757014900858847; 1757014900868335]
# EventStore containing 50 events within 9469µs duration; time range within [1757014900868886; 1757014900878355]
# EventStore containing 50 events within 9453µs duration; time range within [1757014900878897; 1757014900888350]
# EventStore containing 82 events within 9729µs duration; time range within [1757014900888808; 1757014900898537]
# EventStore containing 32 events within 9683µs duration; time range within [1757014900898614; 1757014900908297]
# EventStore containing 46 events within 9918µs duration; time range within [1757014900908591; 1757014900918509]
# EventStore containing 49 events within 9681µs duration; time range within [1757014900918883; 1757014900928564]
# EventStore containing 89 events within 9354µs duration; time range within [1757014900928930; 1757014900938284]
# EventStore containing 48 events within 9494µs duration; time range within [1757014900939060; 1757014900948554]
# EventStore containing 49 events within 9393µs duration; time range within [1757014900948884; 1757014900958277]
# EventStore containing 43 events within 9570µs duration; time range within [1757014900959008; 1757014900968578]
# EventStore containing 67 events within 9848µs duration; time range within [1757014900968701; 1757014900978549]
# EventStore containing 38 events within 9372µs duration; time range within [1757014900978639; 1757014900988011]
# EventStore containing 59 events within 9443µs duration; time range within [1757014900989002; 1757014900998445]
# EventStore containing 54 events within 9526µs duration; time range within [1757014900998842; 1757014901008368]
# EventStore containing 72 events within 9883µs duration; time range within [1757014901008605; 1757014901018488]
# EventStore containing 58 events within 9353µs duration; time range within [1757014901018908; 1757014901028261]
# EventStore containing 42 events within 9732µs duration; time range within [1757014901028769; 1757014901038501]
# EventStore containing 63 events within 9881µs duration; time range within [1757014901038641; 1757014901048522]
# EventStore containing 48 events within 9909µs duration; time range within [1757014901048594; 1757014901058503]
# EventStore containing 42 events within 9345µs duration; time range within [1757014901059005; 1757014901068350]
# EventStore containing 45 events within 9788µs duration; time range within [1757014901068695; 1757014901078483]
# EventStore containing 72 events within 9706µs duration; time range within [1757014901078808; 1757014901088514]
# EventStore containing 65 events within 9749µs duration; time range within [1757014901088817; 1757014901098566]
# EventStore containing 41 events within 9543µs duration; time range within [1757014901098687; 1757014901108230]
# EventStore containing 71 events within 9888µs duration; time range within [1757014901108602; 1757014901118490]
# EventStore containing 75 events within 9563µs duration; time range within [1757014901118607; 1757014901128170]
# EventStore containing 52 events within 9769µs duration; time range within [1757014901128611; 1757014901138380]
# EventStore containing 37 events within 9417µs duration; time range within [1757014901138869; 1757014901148286]
# EventStore containing 76 events within 9599µs duration; time range within [1757014901148926; 1757014901158525]
# EventStore containing 72 events within 9437µs duration; time range within [1757014901158829; 1757014901168266]
# EventStore containing 46 events within 9644µs duration; time range within [1757014901168584; 1757014901178228]
# EventStore containing 43 events within 9430µs duration; time range within [1757014901178719; 1757014901188149]
# EventStore containing 75 events within 9571µs duration; time range within [1757014901188786; 1757014901198357]
# EventStore containing 89 events within 9820µs duration; time range within [1757014901198699; 1757014901208519]
# EventStore containing 38 events within 9770µs duration; time range within [1757014901208778; 1757014901218548]
# EventStore containing 52 events within 9742µs duration; time range within [1757014901218766; 1757014901228508]
# EventStore containing 66 events within 9876µs duration; time range within [1757014901228673; 1757014901238549]
# EventStore containing 56 events within 9949µs duration; time range within [1757014901238600; 1757014901248549]
# EventStore containing 41 events within 9607µs duration; time range within [1757014901248841; 1757014901258448]
# EventStore containing 41 events within 9252µs duration; time range within [1757014901258866; 1757014901268118]
# EventStore containing 85 events within 9637µs duration; time range within [1757014901268853; 1757014901278490]
# EventStore containing 59 events within 9110µs duration; time range within [1757014901278599; 1757014901287709]
# EventStore containing 44 events within 9688µs duration; time range within [1757014901288859; 1757014901298547]
# EventStore containing 47 events within 9747µs duration; time range within [1757014901298669; 1757014901308416]
# EventStore containing 75 events within 9743µs duration; time range within [1757014901308826; 1757014901318569]
# EventStore containing 55 events within 9879µs duration; time range within [1757014901318593; 1757014901328472]
# EventStore containing 56 events within 9735µs duration; time range within [1757014901328632; 1757014901338367]
# EventStore containing 67 events within 9555µs duration; time range within [1757014901338748; 1757014901348303]
# EventStore containing 59 events within 9809µs duration; time range within [1757014901348681; 1757014901358490]
# EventStore containing 57 events within 9206µs duration; time range within [1757014901358700; 1757014901367906]
# EventStore containing 37 events within 8038µs duration; time range within [1757014901369027; 1757014901377065]
# EventStore containing 67 events within 9886µs duration; time range within [1757014901378635; 1757014901388521]
# EventStore containing 86 events within 9700µs duration; time range within [1757014901388711; 1757014901398411]
# EventStore containing 60 events within 9828µs duration; time range within [1757014901398581; 1757014901408409]
# EventStore containing 32 events within 9566µs duration; time range within [1757014901408734; 1757014901418300]
# EventStore containing 56 events within 8694µs duration; time range within [1757014901419672; 1757014901428366]
# EventStore containing 61 events within 9859µs duration; time range within [1757014901428686; 1757014901438545]
# EventStore containing 48 events within 9690µs duration; time range within [1757014901438651; 1757014901448341]
# EventStore containing 44 events within 9857µs duration; time range within [1757014901448622; 1757014901458479]
# EventStore containing 70 events within 9882µs duration; time range within [1757014901458673; 1757014901468555]
# EventStore containing 75 events within 9793µs duration; time range within [1757014901468673; 1757014901478466]
# EventStore containing 48 events within 9772µs duration; time range within [1757014901478746; 1757014901488518]
# EventStore containing 44 events within 9824µs duration; time range within [1757014901488702; 1757014901498526]
# EventStore containing 91 events within 9618µs duration; time range within [1757014901498954; 1757014901508572]
# EventStore containing 64 events within 9735µs duration; time range within [1757014901508705; 1757014901518440]
# EventStore containing 30 events within 8619µs duration; time range within [1757014901519052; 1757014901527671]
# EventStore containing 48 events within 9850µs duration; time range within [1757014901528584; 1757014901538434]
# EventStore containing 104 events within 9786µs duration; time range within [1757014901538740; 1757014901548526]
# EventStore containing 40 events within 9819µs duration; time range within [1757014901548622; 1757014901558441]
# EventStore containing 39 events within 9630µs duration; time range within [1757014901558798; 1757014901568428]
# EventStore containing 49 events within 9720µs duration; time range within [1757014901568804; 1757014901578524]
# EventStore containing 74 events within 9862µs duration; time range within [1757014901578664; 1757014901588526]
# EventStore containing 67 events within 9843µs duration; time range within [1757014901588641; 1757014901598484]
# EventStore containing 52 events within 9472µs duration; time range within [1757014901599082; 1757014901608554]
# EventStore containing 63 events within 9290µs duration; time range within [1757014901609113; 1757014901618403]
# EventStore containing 91 events within 9757µs duration; time range within [1757014901618610; 1757014901628367]
# EventStore containing 65 events within 9867µs duration; time range within [1757014901628602; 1757014901638469]
# EventStore containing 42 events within 9879µs duration; time range within [1757014901638664; 1757014901648543]
# EventStore containing 53 events within 9878µs duration; time range within [1757014901648660; 1757014901658538]
# EventStore containing 66 events within 9221µs duration; time range within [1757014901658622; 1757014901667843]
# EventStore containing 45 events within 9599µs duration; time range within [1757014901668698; 1757014901678297]
# EventStore containing 38 events within 9710µs duration; time range within [1757014901678674; 1757014901688384]
# EventStore containing 68 events within 9550µs duration; time range within [1757014901688854; 1757014901698404]
# EventStore containing 70 events within 9831µs duration; time range within [1757014901698629; 1757014901708460]
# EventStore containing 37 events within 9245µs duration; time range within [1757014901709333; 1757014901718578]
# EventStore containing 53 events within 9028µs duration; time range within [1757014901719281; 1757014901728309]
# EventStore containing 66 events within 9781µs duration; time range within [1757014901728693; 1757014901738474]
# EventStore containing 75 events within 9646µs duration; time range within [1757014901738789; 1757014901748435]
# EventStore containing 62 events within 9265µs duration; time range within [1757014901748901; 1757014901758166]
# EventStore containing 60 events within 9180µs duration; time range within [1757014901759256; 1757014901768436]
# EventStore containing 45 events within 9301µs duration; time range within [1757014901768972; 1757014901778273]
# EventStore containing 61 events within 9380µs duration; time range within [1757014901779133; 1757014901788513]
# EventStore containing 42 events within 9974µs duration; time range within [1757014901788591; 1757014901798565]
# EventStore containing 79 events within 9801µs duration; time range within [1757014901798746; 1757014901808547]
# EventStore containing 59 events within 9344µs duration; time range within [1757014901809065; 1757014901818409]
# EventStore containing 50 events within 9959µs duration; time range within [1757014901818591; 1757014901828550]
# EventStore containing 31 events within 9513µs duration; time range within [1757014901828916; 1757014901838429]
# EventStore containing 50 events within 9724µs duration; time range within [1757014901838747; 1757014901848471]
# EventStore containing 56 events within 9220µs duration; time range within [1757014901849355; 1757014901858575]
# EventStore containing 77 events within 9763µs duration; time range within [1757014901858623; 1757014901868386]
# EventStore containing 47 events within 9824µs duration; time range within [1757014901868617; 1757014901878441]
# EventStore containing 100 events within 9927µs duration; time range within [1757014901878602; 1757014901888529]
# EventStore containing 44 events within 9951µs duration; time range within [1757014901888584; 1757014901898535]
# EventStore containing 39 events within 9801µs duration; time range within [1757014901898699; 1757014901908500]
# EventStore containing 48 events within 9724µs duration; time range within [1757014901908842; 1757014901918566]
# EventStore containing 68 events within 9642µs duration; time range within [1757014901918600; 1757014901928242]
# EventStore containing 73 events within 9680µs duration; time range within [1757014901928810; 1757014901938490]
# EventStore containing 37 events within 8947µs duration; time range within [1757014901938927; 1757014901947874]
# EventStore containing 50 events within 9440µs duration; time range within [1757014901948875; 1757014901958315]
# EventStore containing 57 events within 9913µs duration; time range within [1757014901958634; 1757014901968547]
# EventStore containing 87 events within 9300µs duration; time range within [1757014901968981; 1757014901978281]
# EventStore containing 38 events within 9352µs duration; time range within [1757014901979133; 1757014901988485]
# EventStore containing 53 events within 9381µs duration; time range within [1757014901989033; 1757014901998414]
# EventStore containing 77 events within 9718µs duration; time range within [1757014901998753; 1757014902008471]
# EventStore containing 51 events within 9799µs duration; time range within [1757014902008713; 1757014902018512]
# EventStore containing 36 events within 9803µs duration; time range within [1757014902018593; 1757014902028396]
# EventStore containing 57 events within 9799µs duration; time range within [1757014902028725; 1757014902038524]
# EventStore containing 72 events within 9685µs duration; time range within [1757014902038746; 1757014902048431]
# EventStore containing 86 events within 9255µs duration; time range within [1757014902048590; 1757014902057845]
# EventStore containing 59 events within 9786µs duration; time range within [1757014902058741; 1757014902068527]
# EventStore containing 66 events within 9683µs duration; time range within [1757014902068880; 1757014902078563]
# EventStore containing 75 events within 9968µs duration; time range within [1757014902078584; 1757014902088552]
# EventStore containing 47 events within 9069µs duration; time range within [1757014902089231; 1757014902098300]
# EventStore containing 39 events within 9717µs duration; time range within [1757014902098759; 1757014902108476]
# EventStore containing 84 events within 9654µs duration; time range within [1757014902108687; 1757014902118341]
# EventStore containing 74 events within 9872µs duration; time range within [1757014902118662; 1757014902128534]
# EventStore containing 33 events within 9888µs duration; time range within [1757014902128655; 1757014902138543]
# EventStore containing 47 events within 9732µs duration; time range within [1757014902138780; 1757014902148512]
# EventStore containing 70 events within 9850µs duration; time range within [1757014902148721; 1757014902158571]
# EventStore containing 59 events within 9523µs duration; time range within [1757014902158582; 1757014902168105]
# EventStore containing 31 events within 8925µs duration; time range within [1757014902169646; 1757014902178571]
# EventStore containing 34 events within 8928µs duration; time range within [1757014902179617; 1757014902188545]
# EventStore containing 93 events within 9522µs duration; time range within [1757014902188916; 1757014902198438]
# EventStore containing 60 events within 9576µs duration; time range within [1757014902198906; 1757014902208482]
# EventStore containing 57 events within 9814µs duration; time range within [1757014902208647; 1757014902218461]
# EventStore containing 49 events within 9777µs duration; time range within [1757014902218609; 1757014902228386]
# EventStore containing 61 events within 9138µs duration; time range within [1757014902228810; 1757014902237948]
# EventStore containing 62 events within 9925µs duration; time range within [1757014902238644; 1757014902248569]
# EventStore containing 44 events within 9215µs duration; time range within [1757014902248909; 1757014902258124]
# EventStore containing 54 events within 9644µs duration; time range within [1757014902258725; 1757014902268369]
# EventStore containing 94 events within 9844µs duration; time range within [1757014902268687; 1757014902278531]
# EventStore containing 43 events within 9444µs duration; time range within [1757014902278796; 1757014902288240]
# EventStore containing 45 events within 8755µs duration; time range within [1757014902288795; 1757014902297550]
# EventStore containing 53 events within 8314µs duration; time range within [1757014902300168; 1757014902308482]
# EventStore containing 56 events within 9792µs duration; time range within [1757014902308665; 1757014902318457]
# EventStore containing 43 events within 9512µs duration; time range within [1757014902318738; 1757014902328250]
# EventStore containing 57 events within 9942µs duration; time range within [1757014902328631; 1757014902338573]
# EventStore containing 86 events within 9372µs duration; time range within [1757014902338985; 1757014902348357]
# EventStore containing 85 events within 9815µs duration; time range within [1757014902348693; 1757014902358508]
# EventStore containing 36 events within 9822µs duration; time range within [1757014902358669; 1757014902368491]
# EventStore containing 37 events within 9780µs duration; time range within [1757014902368779; 1757014902378559]
# EventStore containing 65 events within 9172µs duration; time range within [1757014902378881; 1757014902388053]
# EventStore containing 81 events within 9820µs duration; time range within [1757014902388622; 1757014902398442]
# EventStore containing 40 events within 9228µs duration; time range within [1757014902399090; 1757014902408318]
# EventStore containing 32 events within 9117µs duration; time range within [1757014902409436; 1757014902418553]
# EventStore containing 103 events within 9978µs duration; time range within [1757014902418594; 1757014902428572]
# EventStore containing 75 events within 9431µs duration; time range within [1757014902428695; 1757014902438126]
# EventStore containing 37 events within 9023µs duration; time range within [1757014902439490; 1757014902448513]
# EventStore containing 60 events within 9663µs duration; time range within [1757014902448775; 1757014902458438]
# EventStore containing 72 events within 9132µs duration; time range within [1757014902458737; 1757014902467869]
# EventStore containing 55 events within 8626µs duration; time range within [1757014902468755; 1757014902477381]
# EventStore containing 39 events within 9415µs duration; time range within [1757014902479036; 1757014902488451]
# EventStore containing 65 events within 9278µs duration; time range within [1757014902489176; 1757014902498454]
# EventStore containing 72 events within 9719µs duration; time range within [1757014902498633; 1757014902508352]
# EventStore containing 59 events within 9501µs duration; time range within [1757014902508658; 1757014902518159]
# EventStore containing 60 events within 9370µs duration; time range within [1757014902518763; 1757014902528133]
# EventStore containing 65 events within 9691µs duration; time range within [1757014902528866; 1757014902538557]
# EventStore containing 67 events within 9563µs duration; time range within [1757014902538858; 1757014902548421]
# EventStore containing 60 events within 9922µs duration; time range within [1757014902548639; 1757014902558561]
# EventStore containing 46 events within 9006µs duration; time range within [1757014902559054; 1757014902568060]
# EventStore containing 84 events within 9593µs duration; time range within [1757014902568682; 1757014902578275]
# EventStore containing 74 events within 9907µs duration; time range within [1757014902578595; 1757014902588502]
# EventStore containing 45 events within 9731µs duration; time range within [1757014902588796; 1757014902598527]
# EventStore containing 48 events within 9894µs duration; time range within [1757014902598615; 1757014902608509]
# EventStore containing 83 events within 9525µs duration; time range within [1757014902608746; 1757014902618271]
# EventStore containing 72 events within 9671µs duration; time range within [1757014902618803; 1757014902628474]
# EventStore containing 57 events within 9855µs duration; time range within [1757014902628596; 1757014902638451]
# EventStore containing 57 events within 9107µs duration; time range within [1757014902638638; 1757014902647745]
# EventStore containing 93 events within 9537µs duration; time range within [1757014902648619; 1757014902658156]
# EventStore containing 61 events within 9830µs duration; time range within [1757014902658665; 1757014902668495]
# EventStore containing 60 events within 9197µs duration; time range within [1757014902668626; 1757014902677823]
# EventStore containing 44 events within 9493µs duration; time range within [1757014902679061; 1757014902688554]
# EventStore containing 67 events within 9881µs duration; time range within [1757014902688593; 1757014902698474]
# EventStore containing 60 events within 9840µs duration; time range within [1757014902698687; 1757014902708527]
# EventStore containing 46 events within 8733µs duration; time range within [1757014902709752; 1757014902718485]
# EventStore containing 82 events within 9853µs duration; time range within [1757014902718695; 1757014902728548]
# EventStore containing 72 events within 9692µs duration; time range within [1757014902728657; 1757014902738349]
# EventStore containing 47 events within 9665µs duration; time range within [1757014902738794; 1757014902748459]
# EventStore containing 31 events within 9541µs duration; time range within [1757014902748719; 1757014902758260]
# EventStore containing 75 events within 9917µs duration; time range within [1757014902758637; 1757014902768554]
# EventStore containing 101 events within 9826µs duration; time range within [1757014902768586; 1757014902778412]
# EventStore containing 42 events within 9916µs duration; time range within [1757014902778591; 1757014902788507]
# EventStore containing 52 events within 8626µs duration; time range within [1757014902788723; 1757014902797349]
# EventStore containing 79 events within 9698µs duration; time range within [1757014902798739; 1757014902808437]
# EventStore containing 82 events within 9872µs duration; time range within [1757014902808637; 1757014902818509]
# EventStore containing 21 events within 9057µs duration; time range within [1757014902819087; 1757014902828144]
# EventStore containing 43 events within 9430µs duration; time range within [1757014902829000; 1757014902838430]
# EventStore containing 85 events within 9813µs duration; time range within [1757014902838765; 1757014902848578]
# EventStore containing 62 events within 9046µs duration; time range within [1757014902848598; 1757014902857644]
# EventStore containing 33 events within 9405µs duration; time range within [1757014902859123; 1757014902868528]
# EventStore containing 57 events within 9925µs duration; time range within [1757014902868647; 1757014902878572]
# EventStore containing 79 events within 9591µs duration; time range within [1757014902878791; 1757014902888382]
# EventStore containing 67 events within 9789µs duration; time range within [1757014902888687; 1757014902898476]
# EventStore containing 34 events within 9829µs duration; time range within [1757014902898669; 1757014902908498]
# EventStore containing 50 events within 9204µs duration; time range within [1757014902909281; 1757014902918485]
# EventStore containing 79 events within 9658µs duration; time range within [1757014902918736; 1757014902928394]
# EventStore containing 64 events within 9906µs duration; time range within [1757014902928623; 1757014902938529]
# EventStore containing 52 events within 9765µs duration; time range within [1757014902938722; 1757014902948487]
# EventStore containing 80 events within 9541µs duration; time range within [1757014902948687; 1757014902958228]
# EventStore containing 80 events within 9850µs duration; time range within [1757014902958727; 1757014902968577]
# EventStore containing 53 events within 9682µs duration; time range within [1757014902968606; 1757014902978288]
# EventStore containing 45 events within 9544µs duration; time range within [1757014902978847; 1757014902988391]
# EventStore containing 87 events within 9804µs duration; time range within [1757014902988739; 1757014902998543]
# EventStore containing 82 events within 9903µs duration; time range within [1757014902998634; 1757014903008537]
# EventStore containing 57 events within 9543µs duration; time range within [1757014903008590; 1757014903018133]
# EventStore containing 38 events within 9590µs duration; time range within [1757014903018847; 1757014903028437]
# EventStore containing 73 events within 9791µs duration; time range within [1757014903028718; 1757014903038509]
# EventStore containing 88 events within 9652µs duration; time range within [1757014903038830; 1757014903048482]
# EventStore containing 44 events within 9634µs duration; time range within [1757014903048597; 1757014903058231]
# EventStore containing 47 events within 9784µs duration; time range within [1757014903058626; 1757014903068410]
# EventStore containing 76 events within 9750µs duration; time range within [1757014903068626; 1757014903078376]
# EventStore containing 66 events within 9859µs duration; time range within [1757014903078697; 1757014903088556]
# EventStore containing 36 events within 9435µs duration; time range within [1757014903088818; 1757014903098253]
# EventStore containing 57 events within 9957µs duration; time range within [1757014903098619; 1757014903108576]
# EventStore containing 66 events within 9813µs duration; time range within [1757014903108686; 1757014903118499]
# EventStore containing 74 events within 9010µs duration; time range within [1757014903118882; 1757014903127892]
# EventStore containing 41 events within 9321µs duration; time range within [1757014903129250; 1757014903138571]
# EventStore containing 53 events within 9585µs duration; time range within [1757014903138864; 1757014903148449]
# EventStore containing 83 events within 9475µs duration; time range within [1757014903148934; 1757014903158409]
# EventStore containing 59 events within 9280µs duration; time range within [1757014903158695; 1757014903167975]
# EventStore containing 41 events within 9945µs duration; time range within [1757014903168599; 1757014903178544]
# EventStore containing 58 events within 9283µs duration; time range within [1757014903178777; 1757014903188060]
# EventStore containing 84 events within 9798µs duration; time range within [1757014903188587; 1757014903198385]
# EventStore containing 47 events within 9906µs duration; time range within [1757014903198617; 1757014903208523]
# EventStore containing 42 events within 9615µs duration; time range within [1757014903208633; 1757014903218248]
# EventStore containing 79 events within 9761µs duration; time range within [1757014903218796; 1757014903228557]
# EventStore containing 93 events within 9887µs duration; time range within [1757014903228607; 1757014903238494]
# EventStore containing 52 events within 9710µs duration; time range within [1757014903238614; 1757014903248324]
# EventStore containing 42 events within 9740µs duration; time range within [1757014903248783; 1757014903258523]
# EventStore containing 88 events within 9776µs duration; time range within [1757014903258670; 1757014903268446]
# EventStore containing 80 events within 9948µs duration; time range within [1757014903268590; 1757014903278538]
# EventStore containing 47 events within 9924µs duration; time range within [1757014903278630; 1757014903288554]
# EventStore containing 49 events within 9679µs duration; time range within [1757014903288850; 1757014903298529]
# EventStore containing 77 events within 9424µs duration; time range within [1757014903299128; 1757014903308552]
# EventStore containing 89 events within 9426µs duration; time range within [1757014903309047; 1757014903318473]
# EventStore containing 33 events within 9004µs duration; time range within [1757014903319346; 1757014903328350]
# EventStore containing 67 events within 9679µs duration; time range within [1757014903328825; 1757014903338504]
# EventStore containing 67 events within 9879µs duration; time range within [1757014903338654; 1757014903348533]
# EventStore containing 67 events within 9666µs duration; time range within [1757014903348897; 1757014903358563]
# EventStore containing 36 events within 9547µs duration; time range within [1757014903358740; 1757014903368287]
# EventStore containing 61 events within 9742µs duration; time range within [1757014903368771; 1757014903378513]
# EventStore containing 76 events within 9385µs duration; time range within [1757014903379106; 1757014903388491]
# EventStore containing 61 events within 9915µs duration; time range within [1757014903388654; 1757014903398569]
# EventStore containing 41 events within 9504µs duration; time range within [1757014903398931; 1757014903408435]
# EventStore containing 47 events within 9487µs duration; time range within [1757014903408862; 1757014903418349]
# EventStore containing 84 events within 9944µs duration; time range within [1757014903418632; 1757014903428576]
# EventStore containing 74 events within 9826µs duration; time range within [1757014903428585; 1757014903438411]
# EventStore containing 50 events within 9925µs duration; time range within [1757014903438587; 1757014903448512]
# EventStore containing 62 events within 9861µs duration; time range within [1757014903448685; 1757014903458546]
# EventStore containing 85 events within 9794µs duration; time range within [1757014903458617; 1757014903468411]
# EventStore containing 31 events within 9466µs duration; time range within [1757014903469090; 1757014903478556]
# EventStore containing 52 events within 9856µs duration; time range within [1757014903478612; 1757014903488468]
# EventStore containing 87 events within 9743µs duration; time range within [1757014903488758; 1757014903498501]
# EventStore containing 59 events within 9861µs duration; time range within [1757014903498648; 1757014903508509]
# EventStore containing 36 events within 9939µs duration; time range within [1757014903508584; 1757014903518523]
# EventStore containing 35 events within 8526µs duration; time range within [1757014903519815; 1757014903528341]
# EventStore containing 62 events within 9472µs duration; time range within [1757014903529071; 1757014903538543]
# EventStore containing 61 events within 9929µs duration; time range within [1757014903538591; 1757014903548520]
# EventStore containing 53 events within 9941µs duration; time range within [1757014903548597; 1757014903558538]
# EventStore containing 37 events within 9681µs duration; time range within [1757014903558681; 1757014903568362]
# EventStore containing 83 events within 9892µs duration; time range within [1757014903568662; 1757014903578554]
# EventStore containing 51 events within 9463µs duration; time range within [1757014903579080; 1757014903588543]
# EventStore containing 36 events within 9418µs duration; time range within [1757014903588787; 1757014903598205]
# EventStore containing 40 events within 9897µs duration; time range within [1757014903598682; 1757014903608579]
# EventStore containing 97 events within 9913µs duration; time range within [1757014903608584; 1757014903618497]
# EventStore containing 53 events within 9720µs duration; time range within [1757014903618626; 1757014903628346]
# EventStore containing 43 events within 9499µs duration; time range within [1757014903628699; 1757014903638198]
# EventStore containing 54 events within 8465µs duration; time range within [1757014903640010; 1757014903648475]
# EventStore containing 64 events within 9478µs duration; time range within [1757014903648868; 1757014903658346]
# EventStore containing 61 events within 9537µs duration; time range within [1757014903658634; 1757014903668171]
# EventStore containing 37 events within 9777µs duration; time range within [1757014903668757; 1757014903678534]
# EventStore containing 59 events within 9850µs duration; time range within [1757014903678593; 1757014903688443]
# EventStore containing 124 events within 9886µs duration; time range within [1757014903688588; 1757014903698474]
# EventStore containing 71 events within 9735µs duration; time range within [1757014903698656; 1757014903708391]
# EventStore containing 31 events within 8059µs duration; time range within [1757014903709038; 1757014903717097]
# EventStore containing 72 events within 9759µs duration; time range within [1757014903718710; 1757014903728469]
# EventStore containing 65 events within 9699µs duration; time range within [1757014903728837; 1757014903738536]
# EventStore containing 54 events within 9867µs duration; time range within [1757014903738588; 1757014903748455]
# EventStore containing 31 events within 9150µs duration; time range within [1757014903749004; 1757014903758154]
# EventStore containing 74 events within 9885µs duration; time range within [1757014903758617; 1757014903768502]
# EventStore containing 73 events within 9624µs duration; time range within [1757014903768648; 1757014903778272]
# EventStore containing 53 events within 9862µs duration; time range within [1757014903778656; 1757014903788518]
# EventStore containing 46 events within 9718µs duration; time range within [1757014903788850; 1757014903798568]
# EventStore containing 93 events within 9759µs duration; time range within [1757014903798685; 1757014903808444]
# EventStore containing 47 events within 9938µs duration; time range within [1757014903808585; 1757014903818523]
# EventStore containing 60 events within 9689µs duration; time range within [1757014903818703; 1757014903828392]
# EventStore containing 44 events within 9249µs duration; time range within [1757014903829042; 1757014903838291]
# EventStore containing 69 events within 9590µs duration; time range within [1757014903838984; 1757014903848574]
# EventStore containing 62 events within 9325µs duration; time range within [1757014903848621; 1757014903857946]
# EventStore containing 54 events within 9314µs duration; time range within [1757014903859123; 1757014903868437]
# EventStore containing 65 events within 9620µs duration; time range within [1757014903868925; 1757014903878545]
# EventStore containing 89 events within 9800µs duration; time range within [1757014903878755; 1757014903888555]
# EventStore containing 58 events within 9176µs duration; time range within [1757014903888742; 1757014903897918]
# EventStore containing 45 events within 9493µs duration; time range within [1757014903898629; 1757014903908122]
# EventStore containing 54 events within 9241µs duration; time range within [1757014903908735; 1757014903917976]
# EventStore containing 73 events within 9459µs duration; time range within [1757014903918706; 1757014903928165]
# EventStore containing 51 events within 9666µs duration; time range within [1757014903928745; 1757014903938411]
# EventStore containing 41 events within 9682µs duration; time range within [1757014903938751; 1757014903948433]
# EventStore containing 51 events within 9603µs duration; time range within [1757014903948769; 1757014903958372]
# EventStore containing 83 events within 9891µs duration; time range within [1757014903958660; 1757014903968551]
# EventStore containing 36 events within 8537µs duration; time range within [1757014903968833; 1757014903977370]
# EventStore containing 58 events within 9817µs duration; time range within [1757014903978641; 1757014903988458]
# EventStore containing 66 events within 9302µs duration; time range within [1757014903988973; 1757014903998275]
# EventStore containing 70 events within 9971µs duration; time range within [1757014903998605; 1757014904008576]
# EventStore containing 36 events within 9182µs duration; time range within [1757014904009326; 1757014904018508]
# EventStore containing 53 events within 9682µs duration; time range within [1757014904018646; 1757014904028328]
# EventStore containing 70 events within 9951µs duration; time range within [1757014904028593; 1757014904038544]
# EventStore containing 78 events within 9611µs duration; time range within [1757014904038948; 1757014904048559]
# EventStore containing 39 events within 9611µs duration; time range within [1757014904048786; 1757014904058397]
# EventStore containing 83 events within 9611µs duration; time range within [1757014904058894; 1757014904068505]
# EventStore containing 76 events within 9793µs duration; time range within [1757014904068609; 1757014904078402]
# EventStore containing 66 events within 9340µs duration; time range within [1757014904079017; 1757014904088357]
# EventStore containing 44 events within 9781µs duration; time range within [1757014904088706; 1757014904098487]
# EventStore containing 66 events within 9619µs duration; time range within [1757014904098621; 1757014904108240]
# EventStore containing 67 events within 9436µs duration; time range within [1757014904108750; 1757014904118186]
# EventStore containing 60 events within 9817µs duration; time range within [1757014904118755; 1757014904128572]
# EventStore containing 40 events within 9668µs duration; time range within [1757014904128754; 1757014904138422]
# EventStore containing 95 events within 9904µs duration; time range within [1757014904138669; 1757014904148573]
# EventStore containing 71 events within 9682µs duration; time range within [1757014904148592; 1757014904158274]
# EventStore containing 43 events within 8932µs duration; time range within [1757014904158750; 1757014904167682]
# EventStore containing 42 events within 9233µs duration; time range within [1757014904169277; 1757014904178510]
# EventStore containing 92 events within 9930µs duration; time range within [1757014904178591; 1757014904188521]
# EventStore containing 74 events within 9787µs duration; time range within [1757014904188778; 1757014904198565]
# EventStore containing 60 events within 9671µs duration; time range within [1757014904198668; 1757014904208339]
# ...
# EventStore containing 119 events within 9530µs duration; time range within [1757014929668835; 1757014929678365]
# EventStore containing 105 events within 9957µs duration; time range within [1757014929678589; 1757014929688546]
# EventStore containing 78 events within 9218µs duration; time range within [1757014929688714; 1757014929697932]
# EventStore containing 58 events within 9594µs duration; time range within [1757014929698957; 1757014929708551]
# EventStore containing 112 events within 9949µs duration; time range within [1757014929708607; 1757014929718556]
# EventStore containing 119 events within 9927µs duration; time range within [1757014929718634; 1757014929728561]
# EventStore containing 35 events within 9820µs duration; time range within [1757014929728609; 1757014929738429]
# EventStore containing 83 events within 9866µs duration; time range within [1757014929738622; 1757014929748488]
# EventStore containing 112 events within 9928µs duration; time range within [1757014929748633; 1757014929758561]
# EventStore containing 118 events within 9782µs duration; time range within [1757014929758584; 1757014929768366]
# EventStore containing 57 events within 9923µs duration; time range within [1757014929768609; 1757014929778532]
# EventStore containing 87 events within 9543µs duration; time range within [1757014929778980; 1757014929788523]
# EventStore containing 101 events within 9883µs duration; time range within [1757014929788622; 1757014929798505]
# EventStore containing 82 events within 9895µs duration; time range within [1757014929798608; 1757014929808503]
# EventStore containing 53 events within 9195µs duration; time range within [1757014929809219; 1757014929818414]
# EventStore containing 67 events within 9969µs duration; time range within [1757014929818610; 1757014929828579]
# EventStore containing 110 events within 9779µs duration; time range within [1757014929828718; 1757014929838497]
# EventStore containing 56 events within 9565µs duration; time range within [1757014929838624; 1757014929848189]
# EventStore containing 72 events within 9574µs duration; time range within [1757014929848599; 1757014929858173]
# EventStore containing 81 events within 9604µs duration; time range within [1757014929858812; 1757014929868416]
# EventStore containing 168 events within 9866µs duration; time range within [1757014929868680; 1757014929878546]
# EventStore containing 55 events within 9583µs duration; time range within [1757014929878608; 1757014929888191]
# EventStore containing 48 events within 9237µs duration; time range within [1757014929889046; 1757014929898283]
# EventStore containing 95 events within 9373µs duration; time range within [1757014929899166; 1757014929908539]
# EventStore containing 115 events within 9887µs duration; time range within [1757014929908661; 1757014929918548]
# EventStore containing 39 events within 9080µs duration; time range within [1757014929919406; 1757014929928486]
# EventStore containing 55 events within 9958µs duration; time range within [1757014929928599; 1757014929938557]
# EventStore containing 121 events within 9910µs duration; time range within [1757014929938626; 1757014929948536]
# EventStore containing 83 events within 9583µs duration; time range within [1757014929948905; 1757014929958488]
# EventStore containing 73 events within 9880µs duration; time range within [1757014929958642; 1757014929968522]
# EventStore containing 46 events within 9661µs duration; time range within [1757014929968702; 1757014929978363]
# EventStore containing 119 events within 9601µs duration; time range within [1757014929978816; 1757014929988417]
# EventStore containing 101 events within 9937µs duration; time range within [1757014929988634; 1757014929998571]
# EventStore containing 67 events within 9728µs duration; time range within [1757014929998622; 1757014930008350]
# EventStore containing 98 events within 9911µs duration; time range within [1757014930008653; 1757014930018564]
# EventStore containing 117 events within 9848µs duration; time range within [1757014930018665; 1757014930028513]
# EventStore containing 74 events within 9826µs duration; time range within [1757014930028711; 1757014930038537]
# EventStore containing 55 events within 9979µs duration; time range within [1757014930038600; 1757014930048579]
# EventStore containing 77 events within 9872µs duration; time range within [1757014930048613; 1757014930058485]
# EventStore containing 130 events within 9489µs duration; time range within [1757014930059086; 1757014930068575]
# EventStore containing 92 events within 9761µs duration; time range within [1757014930068659; 1757014930078420]
# EventStore containing 56 events within 8964µs duration; time range within [1757014930078947; 1757014930087911]
# EventStore containing 86 events within 9501µs duration; time range within [1757014930088635; 1757014930098136]
# EventStore containing 106 events within 9966µs duration; time range within [1757014930098582; 1757014930108548]
# EventStore containing 58 events within 9552µs duration; time range within [1757014930108590; 1757014930118142]
# EventStore containing 56 events within 9482µs duration; time range within [1757014930118630; 1757014930128112]
# EventStore containing 95 events within 9869µs duration; time range within [1757014930128696; 1757014930138565]
# EventStore containing 101 events within 9698µs duration; time range within [1757014930138665; 1757014930148363]
# EventStore containing 56 events within 9604µs duration; time range within [1757014930148836; 1757014930158440]
# EventStore containing 63 events within 9712µs duration; time range within [1757014930158617; 1757014930168329]
# EventStore containing 134 events within 9943µs duration; time range within [1757014930168605; 1757014930178548]
# EventStore containing 131 events within 9648µs duration; time range within [1757014930178791; 1757014930188439]
# EventStore containing 56 events within 9948µs duration; time range within [1757014930188596; 1757014930198544]
# EventStore containing 62 events within 9811µs duration; time range within [1757014930198706; 1757014930208517]
# EventStore containing 95 events within 9696µs duration; time range within [1757014930208796; 1757014930218492]
# EventStore containing 91 events within 8896µs duration; time range within [1757014930218599; 1757014930227495]
# EventStore containing 55 events within 9511µs duration; time range within [1757014930228688; 1757014930238199]
# EventStore containing 55 events within 9089µs duration; time range within [1757014930238842; 1757014930247931]
# EventStore containing 79 events within 9898µs duration; time range within [1757014930248671; 1757014930258569]
# EventStore containing 73 events within 9937µs duration; time range within [1757014930258594; 1757014930268531]
# EventStore containing 72 events within 9763µs duration; time range within [1757014930268640; 1757014930278403]
# EventStore containing 81 events within 9520µs duration; time range within [1757014930279037; 1757014930288557]
# EventStore containing 103 events within 9846µs duration; time range within [1757014930288729; 1757014930298575]
# EventStore containing 74 events within 9800µs duration; time range within [1757014930298649; 1757014930308449]
# EventStore containing 43 events within 9693µs duration; time range within [1757014930308728; 1757014930318421]
# EventStore containing 124 events within 9904µs duration; time range within [1757014930318600; 1757014930328504]
# EventStore containing 99 events within 9848µs duration; time range within [1757014930328599; 1757014930338447]
# EventStore containing 60 events within 9882µs duration; time range within [1757014930338603; 1757014930348485]
# EventStore containing 58 events within 9890µs duration; time range within [1757014930348649; 1757014930358539]
# EventStore containing 148 events within 9787µs duration; time range within [1757014930358726; 1757014930368513]
# EventStore containing 152 events within 9812µs duration; time range within [1757014930368724; 1757014930378536]
# EventStore containing 56 events within 9813µs duration; time range within [1757014930378678; 1757014930388491]
# EventStore containing 57 events within 9789µs duration; time range within [1757014930388748; 1757014930398537]
# EventStore containing 124 events within 9900µs duration; time range within [1757014930398657; 1757014930408557]
# EventStore containing 176 events within 9778µs duration; time range within [1757014930408584; 1757014930418362]
# EventStore containing 42 events within 9881µs duration; time range within [1757014930418670; 1757014930428551]
# EventStore containing 59 events within 9835µs duration; time range within [1757014930428593; 1757014930438428]
# EventStore containing 122 events within 9923µs duration; time range within [1757014930438593; 1757014930448516]
# EventStore containing 96 events within 9694µs duration; time range within [1757014930448737; 1757014930458431]
# EventStore containing 50 events within 9603µs duration; time range within [1757014930458894; 1757014930468497]
# EventStore containing 72 events within 9545µs duration; time range within [1757014930468796; 1757014930478341]
# EventStore containing 100 events within 9636µs duration; time range within [1757014930478868; 1757014930488504]
# EventStore containing 96 events within 9920µs duration; time range within [1757014930488631; 1757014930498551]
# EventStore containing 43 events within 9602µs duration; time range within [1757014930498711; 1757014930508313]
# EventStore containing 122 events within 9722µs duration; time range within [1757014930508800; 1757014930518522]
# EventStore containing 131 events within 9611µs duration; time range within [1757014930518595; 1757014930528206]
# EventStore containing 77 events within 9807µs duration; time range within [1757014930528588; 1757014930538395]
# EventStore containing 54 events within 9880µs duration; time range within [1757014930538598; 1757014930548478]
# EventStore containing 98 events within 9786µs duration; time range within [1757014930548763; 1757014930558549]
# EventStore containing 126 events within 9719µs duration; time range within [1757014930558652; 1757014930568371]
# EventStore containing 70 events within 9862µs duration; time range within [1757014930568613; 1757014930578475]
# EventStore containing 49 events within 9611µs duration; time range within [1757014930578857; 1757014930588468]
# EventStore containing 78 events within 9805µs duration; time range within [1757014930588697; 1757014930598502]
# EventStore containing 103 events within 9392µs duration; time range within [1757014930599122; 1757014930608514]
# EventStore containing 42 events within 9712µs duration; time range within [1757014930608745; 1757014930618457]
# EventStore containing 60 events within 9528µs duration; time range within [1757014930618836; 1757014930628364]
# EventStore containing 106 events within 9947µs duration; time range within [1757014930628615; 1757014930638562]
# EventStore containing 78 events within 9825µs duration; time range within [1757014930638648; 1757014930648473]
# EventStore containing 67 events within 9891µs duration; time range within [1757014930648593; 1757014930658484]
# EventStore containing 75 events within 9885µs duration; time range within [1757014930658694; 1757014930668579]
# EventStore containing 77 events within 9667µs duration; time range within [1757014930668817; 1757014930678484]
# EventStore containing 83 events within 9745µs duration; time range within [1757014930678586; 1757014930688331]
# EventStore containing 47 events within 9439µs duration; time range within [1757014930689054; 1757014930698493]
# EventStore containing 67 events within 9827µs duration; time range within [1757014930698628; 1757014930708455]
# EventStore containing 79 events within 9863µs duration; time range within [1757014930708657; 1757014930718520]
# EventStore containing 63 events within 9781µs duration; time range within [1757014930718637; 1757014930728418]
# EventStore containing 74 events within 9538µs duration; time range within [1757014930729008; 1757014930738546]
# EventStore containing 76 events within 9948µs duration; time range within [1757014930738600; 1757014930748548]
# EventStore containing 178 events within 9864µs duration; time range within [1757014930748590; 1757014930758454]
# EventStore containing 95 events within 9591µs duration; time range within [1757014930758587; 1757014930768178]
# EventStore containing 56 events within 9891µs duration; time range within [1757014930768587; 1757014930778478]
# EventStore containing 88 events within 9520µs duration; time range within [1757014930779005; 1757014930788525]
# EventStore containing 93 events within 9733µs duration; time range within [1757014930788839; 1757014930798572]
# EventStore containing 50 events within 9905µs duration; time range within [1757014930798614; 1757014930808519]
# EventStore containing 42 events within 9724µs duration; time range within [1757014930808623; 1757014930818347]
# EventStore containing 90 events within 9765µs duration; time range within [1757014930818749; 1757014930828514]
# EventStore containing 66 events within 9878µs duration; time range within [1757014930828603; 1757014930838481]
# EventStore containing 62 events within 9759µs duration; time range within [1757014930838587; 1757014930848346]
# EventStore containing 61 events within 9867µs duration; time range within [1757014930848653; 1757014930858520]
# EventStore containing 111 events within 9988µs duration; time range within [1757014930858587; 1757014930868575]
# EventStore containing 108 events within 9801µs duration; time range within [1757014930868617; 1757014930878418]
# EventStore containing 58 events within 9780µs duration; time range within [1757014930878739; 1757014930888519]
# EventStore containing 63 events within 9574µs duration; time range within [1757014930888932; 1757014930898506]
# EventStore containing 144 events within 9674µs duration; time range within [1757014930898601; 1757014930908275]
# EventStore containing 93 events within 9596µs duration; time range within [1757014930908623; 1757014930918219]
# EventStore containing 54 events within 9368µs duration; time range within [1757014930919041; 1757014930928409]
# EventStore containing 69 events within 9963µs duration; time range within [1757014930928610; 1757014930938573]
# EventStore containing 105 events within 9815µs duration; time range within [1757014930938582; 1757014930948397]
# EventStore containing 79 events within 9712µs duration; time range within [1757014930948679; 1757014930958391]
# EventStore containing 75 events within 9642µs duration; time range within [1757014930958824; 1757014930968466]
# EventStore containing 95 events within 9629µs duration; time range within [1757014930968900; 1757014930978529]
# EventStore containing 85 events within 9375µs duration; time range within [1757014930978757; 1757014930988132]
# EventStore containing 89 events within 9696µs duration; time range within [1757014930988662; 1757014930998358]
# EventStore containing 61 events within 9789µs duration; time range within [1757014930998706; 1757014931008495]
# EventStore containing 100 events within 9924µs duration; time range within [1757014931008648; 1757014931018572]
# EventStore containing 68 events within 9867µs duration; time range within [1757014931018620; 1757014931028487]
# EventStore containing 83 events within 9865µs duration; time range within [1757014931028643; 1757014931038508]
# EventStore containing 50 events within 9711µs duration; time range within [1757014931038811; 1757014931048522]
# EventStore containing 145 events within 9866µs duration; time range within [1757014931048611; 1757014931058477]
# EventStore containing 130 events within 9715µs duration; time range within [1757014931058667; 1757014931068382]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 22
#      17     print(events)
#      18     #print(events[0].x())
#      19
#      20 else:
#      21     # No data has arrived yet, short sleep to reduce CPU load
# ---> 22     time.sleep(0.001)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Visualizing each batch

# %%
import cv2 as cv
import dv_processing as dv

# Abrir la cámara
capture = dv.io.camera.open()

if not capture.isEventStreamAvailable():
    raise RuntimeError("Input camera does not provide an event stream.")

# Inicializar visualizador
visualizer = dv.visualization.EventVisualizer(capture.getEventResolution())
visualizer.setBackgroundColor(dv.visualization.colors.white())
visualizer.setPositiveColor(dv.visualization.colors.iniBlue())
visualizer.setNegativeColor(dv.visualization.colors.darkGray())

# Ventana de OpenCV
cv.namedWindow("Preview", cv.WINDOW_NORMAL)

# Loop principal: mostrar imagen cada vez que llegan eventos
while capture.isRunning():
    events = capture.getNextEventBatch()
    if events is not None and len(events) > 0:
        # Generar imagen y mostrarla inmediatamente
        frame = visualizer.generateImage(events)
        cv.imshow("Preview", frame)

    # Salir con ESC
    if cv.waitKey(1) == 27:
        break

cv.destroyAllWindows()
capture.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 28
#      25         cv.imshow("Preview", frame)
#      27     # Salir con ESC
# ---> 28     if cv.waitKey(1) == 27:
#      29         break
#      31 cv.destroyAllWindows()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Event stream slicing

# %% [markdown]
# ### EventStreamSlicer

# %%
import dv_processing as dv
from datetime import timedelta

# Initialize slicer, it will have no jobs at this time
slicer = dv.EventStreamSlicer()


def print_time_interval(events: dv.EventStore):
    # Print the time duration received by this method
    print(f"* Received event with {events.duration()} duration in time-based slicing")


# Register this method to be called every 33 millisecond worth of event data
time_job_id = slicer.doEveryTimeInterval(timedelta(milliseconds=33), print_time_interval)


def print_event_number(events: dv.EventStore):
    # Print the number of events received here
    print(f"# Received {events.size()} events in number-based slicing")


# Register this method to be called every 100 events
number_job_id = slicer.doEveryNumberOfElements(100, print_event_number)

# Implement data generation; The following loop will generate 10 stores
# of events, each containing 100 events within 10 millisecond duration.
for i in range(10):
    # Generate 100 events within 20 millisecond interval. These will be sliced correctly by the slicer.
    store = dv.data.generate.uniformEventsWithinTimeRange(i * 20000, timedelta(milliseconds=20), (100, 100), 100)

    # Now push the store into the slicer, the data contents within the store
    # can be arbitrary, the slicer implementation takes care of correct slicing
    # algorithm and calls the previously registered callbacks accordingly.
    slicer.accept(store)

    # When a packet with index 5 is reached, modify the parameters
    if i == 5:
        # Modify time range to 10 milliseconds instead of 33
        slicer.modifyTimeInterval(time_job_id, timedelta(milliseconds=10))
        # Modify number to 200 instead of 100
        slicer.modifyNumberInterval(number_job_id, 200)
# Out:
# # Received 100 events in number-based slicing
# * Received event with 0:00:00.032800 duration in time-based slicing
# # Received 100 events in number-based slicing
# # Received 100 events in number-based slicing
# * Received event with 0:00:00.032800 duration in time-based slicing
# # Received 100 events in number-based slicing
# * Received event with 0:00:00.032800 duration in time-based slicing
# # Received 100 events in number-based slicing
# # Received 100 events in number-based slicing
# * Received event with 0:00:00.009800 duration in time-based slicing
# * Received event with 0:00:00.009800 duration in time-based slicing
# * Received event with 0:00:00.009800 duration in time-based slicing
# * Received event with 0:00:00.009800 duration in time-based slicing
# * Received event with 0:00:00.009800 duration in time-based slicing
# * Received event with 0:00:00.009800 duration in time-based slicing
# # Received 200 events in number-based slicing
# * Received event with 0:00:00.009800 duration in time-based slicing
# * Received event with 0:00:00.009800 duration in time-based slicing
# * Received event with 0:00:00.009800 duration in time-based slicing
# * Received event with 0:00:00.009800 duration in time-based slicing
# # Received 200 events in number-based slicing

# %% [markdown]
# ### EventVisualizer

# %%
from datetime import timedelta

import cv2 as cv
import dv_processing as dv

# Open any camera
capture = dv.io.camera.open()

# Make sure it supports event stream output, throw an error otherwise
if not capture.isEventStreamAvailable():
    raise RuntimeError("Input camera does not provide an event stream.")

# Initialize an accumulator with some resolution
visualizer = dv.visualization.EventVisualizer(capture.getEventResolution())

# Apply color scheme configuration, these values can be modified to taste
visualizer.setBackgroundColor(dv.visualization.colors.white())
visualizer.setPositiveColor(dv.visualization.colors.iniBlue())
visualizer.setNegativeColor(dv.visualization.colors.darkGray())

# Initialize a preview window
cv.namedWindow("Preview", cv.WINDOW_NORMAL)

# Initialize a slicer
slicer = dv.EventStreamSlicer()


# Declare the callback method for slicer
def slicing_callback(events: dv.EventStore):
    # Generate a preview frame
    frame = visualizer.generateImage(events)

    # Show the accumulated image
    cv.imshow("Preview", frame)
    cv.waitKey(2)


# Register callback to be performed every 33 milliseconds
slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)

# Run the event processing while the camera is connected
while capture.isRunning():
    # Receive events
    events = capture.getNextEventBatch()

    # Check if anything was received
    if events is not None:
        # If so, pass the events into the slicer to handle them
        slicer.accept(events)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 49
#      46 # Check if anything was received
#      47 if events is not None:
#      48     # If so, pass the events into the slicer to handle them
# ---> 49     slicer.accept(events)
#
# Cell In[1], line 35, in slicing_callback(events)
#      33 # Show the accumulated image
#      34 cv.imshow("Preview", frame)
# ---> 35 cv.waitKey(2)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Visualizer on python

# %%
import numpy as np
import cv2 as cv
import dv_processing as dv
from datetime import timedelta

# Abrir la cámara
camera = dv.io.camera.open()
if not camera.isEventStreamAvailable():
    raise RuntimeError("La cámara no proporciona un stream de eventos.")

# Obtener resolución de eventos
res_x, res_y = camera.getEventResolution()

# Crear ventana de OpenCV
cv.namedWindow("Events", cv.WINDOW_NORMAL)

# Crear slicer
slicer = dv.EventStreamSlicer()

# Callback de visualización cada 33 ms
def slicing_callback(events: dv.EventStore):
    if len(events) == 0:
        return

    # Imagen de fondo blanco
    image = 255 * np.ones((res_y, res_x, 3), dtype=np.uint8)

    # Un solo bucle directo sobre los eventos
    for e in events:
        x, y = e.x(), e.y()
        if 0 <= x < res_x and 0 <= y < res_y:
            image[y, x] = (0, 255, 0) if e.polarity() else (0, 0, 255)

    # Mostrar imagen
    cv.imshow("Events", image)
    cv.waitKey(2)

# Registrar el callback en el slicer
slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)

# Loop principal: alimentar el slicer con eventos
while camera.isRunning():
    events = camera.getNextEventBatch()
    if events is not None:
        slicer.accept(events)

    if cv.waitKey(1) == 27:  # salir con ESC
        break

cv.destroyAllWindows()
camera.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 47
#      44     if events is not None:
#      45         slicer.accept(events)
# ---> 47     if cv.waitKey(1) == 27:  # salir con ESC
#      48         break
#      50 cv.destroyAllWindows()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Frame

# %%
import cv2 as cv
import dv_processing as dv

# Open any camera
capture = dv.io.camera.open()

# Initiate a preview window
cv.namedWindow("Preview", cv.WINDOW_NORMAL)

# Run the loop while camera is still connected
while capture.isRunning():
    # Read a frame from the camera
    frame = capture.getNextFrame()

    # The method does not wait for frame arrive, it returns immediately with
    # latest available frame or if no data is available, returns a `None`
    if frame is not None:
        # Print received packet time range
        print(f"Received a frame at time [{frame.timestamp}]")

        # Show a preview of the image
        cv.imshow("Preview", frame.image)
    cv.waitKey(2)
# Out:
# Received a frame at time [1756919996415227]
# Received a frame at time [1756919996452342]
# Received a frame at time [1756919996490579]
# Received a frame at time [1756919996528714]
# Received a frame at time [1756919996566850]
# Received a frame at time [1756919996604886]
# Received a frame at time [1756919996642922]
# Received a frame at time [1756919996680862]
# Received a frame at time [1756919996718802]
# Received a frame at time [1756919996756646]
# Received a frame at time [1756919996794490]
# Received a frame at time [1756919996832241]
# Received a frame at time [1756919996869992]
# Received a frame at time [1756919996907652]
# Received a frame at time [1756919996945312]
# Received a frame at time [1756919996982884]
# Received a frame at time [1756919997020455]
# Received a frame at time [1756919997057938]
# Received a frame at time [1756919997095421]
# Received a frame at time [1756919997132818]
# Received a frame at time [1756919997170215]
# Received a frame at time [1756919997207528]
# Received a frame at time [1756919997244841]
# Received a frame at time [1756919997282069]
# Received a frame at time [1756919997319297]
# Received a frame at time [1756919997356441]
# Received a frame at time [1756919997393586]
# Received a frame at time [1756919997430648]
# Received a frame at time [1756919997467710]
# Received a frame at time [1756919997504692]
# Received a frame at time [1756919997541674]
# Received a frame at time [1756919997578579]
# Received a frame at time [1756919997615484]
# Received a frame at time [1756919997652313]
# Received a frame at time [1756919997689142]
# Received a frame at time [1756919997725896]
# Received a frame at time [1756919997762650]
# Received a frame at time [1756919997799330]
# Received a frame at time [1756919997836011]
# Received a frame at time [1756919997872619]
# Received a frame at time [1756919997909227]
# Received a frame at time [1756919997945765]
# Received a frame at time [1756919997982303]
# Received a frame at time [1756919998018771]
# Received a frame at time [1756919998055239]
# Received a frame at time [1756919998091639]
# Received a frame at time [1756919998128039]
# Received a frame at time [1756919998164372]
# Received a frame at time [1756919998200706]
# Received a frame at time [1756919998236973]
# Received a frame at time [1756919998273240]
# Received a frame at time [1756919998309442]
# Received a frame at time [1756919998345644]
# Received a frame at time [1756919998381783]
# Received a frame at time [1756919998417922]
# Received a frame at time [1756919998454000]
# Received a frame at time [1756919998490078]
# Received a frame at time [1756919998526096]
# Received a frame at time [1756919998562114]
# Received a frame at time [1756919998598074]
# Received a frame at time [1756919998634035]
# Received a frame at time [1756919998669937]
# Received a frame at time [1756919998705839]
# Received a frame at time [1756919998741686]
# Received a frame at time [1756919998777533]
# Received a frame at time [1756919998813326]
# Received a frame at time [1756919998849119]
# Received a frame at time [1756919998884858]
# Received a frame at time [1756919998920597]
# Received a frame at time [1756919998956283]
# Received a frame at time [1756919998991969]
# Received a frame at time [1756919999027605]
# Received a frame at time [1756919999063240]
# Received a frame at time [1756919999098824]
# Received a frame at time [1756919999134408]
# Received a frame at time [1756919999169942]
# Received a frame at time [1756919999205476]
# Received a frame at time [1756919999240963]
# Received a frame at time [1756919999276450]
# Received a frame at time [1756919999311890]
# Received a frame at time [1756919999347330]
# Received a frame at time [1756919999382724]
# Received a frame at time [1756919999418119]
# Received a frame at time [1756919999453469]
# Received a frame at time [1756919999488819]
# Received a frame at time [1756919999524125]
# Received a frame at time [1756919999559431]
# Received a frame at time [1756919999594694]
# Received a frame at time [1756919999629957]
# Received a frame at time [1756919999665178]
# Received a frame at time [1756919999700399]
# Received a frame at time [1756919999735578]
# Received a frame at time [1756919999770757]
# Received a frame at time [1756919999805896]
# Received a frame at time [1756919999841034]
# Received a frame at time [1756919999876132]
# Received a frame at time [1756919999911230]
# Received a frame at time [1756919999946289]
# Received a frame at time [1756919999981348]
# Received a frame at time [1756920000016369]
# Received a frame at time [1756920000051390]
# Received a frame at time [1756920000086374]
# Received a frame at time [1756920000121358]
# Received a frame at time [1756920000156307]
# Received a frame at time [1756920000191257]
# Received a frame at time [1756920000226172]
# Received a frame at time [1756920000261087]
# Received a frame at time [1756920000295967]
# Received a frame at time [1756920000330847]
# Received a frame at time [1756920000365694]
# Received a frame at time [1756920000400541]
# Received a frame at time [1756920000435356]
# Received a frame at time [1756920000470171]
# Received a frame at time [1756920000504955]
# Received a frame at time [1756920000539739]
# Received a frame at time [1756920000574494]
# Received a frame at time [1756920000609248]
# Received a frame at time [1756920000643972]
# Received a frame at time [1756920000678696]
# Received a frame at time [1756920000713391]
# Received a frame at time [1756920000748086]
# Received a frame at time [1756920000782751]
# Received a frame at time [1756920000817416]
# Received a frame at time [1756920000852053]
# Received a frame at time [1756920000886690]
# Received a frame at time [1756920000921301]
# Received a frame at time [1756920000955913]
# Received a frame at time [1756920000990502]
# Received a frame at time [1756920001025091]
# Received a frame at time [1756920001059657]
# Received a frame at time [1756920001094223]
# Received a frame at time [1756920001128766]
# Received a frame at time [1756920001163309]
# Received a frame at time [1756920001197827]
# Received a frame at time [1756920001232345]
# Received a frame at time [1756920001266837]
# Received a frame at time [1756920001301329]
# Received a frame at time [1756920001335795]
# Received a frame at time [1756920001370262]
# Received a frame at time [1756920001404702]
# Received a frame at time [1756920001439142]
# Received a frame at time [1756920001473559]
# Received a frame at time [1756920001507976]
# Received a frame at time [1756920001542371]
# Received a frame at time [1756920001576766]
# Received a frame at time [1756920001611139]
# Received a frame at time [1756920001645512]
# Received a frame at time [1756920001679862]
# Received a frame at time [1756920001714213]
# Received a frame at time [1756920001748539]
# Received a frame at time [1756920001782865]
# Received a frame at time [1756920001817170]
# Received a frame at time [1756920001851475]
# Received a frame at time [1756920001885757]
# Received a frame at time [1756920001920039]
# Received a frame at time [1756920001954300]
# Received a frame at time [1756920001988561]
# Received a frame at time [1756920002022801]
# Received a frame at time [1756920002057041]
# Received a frame at time [1756920002091263]
# Received a frame at time [1756920002125486]
# Received a frame at time [1756920002159689]
# Received a frame at time [1756920002193892]
# Received a frame at time [1756920002228077]
# Received a frame at time [1756920002262262]
# Received a frame at time [1756920002296430]
# Received a frame at time [1756920002330598]
# Received a frame at time [1756920002364749]
# Received a frame at time [1756920002398900]
# Received a frame at time [1756920002433036]
# Received a frame at time [1756920002467173]
# Received a frame at time [1756920002501294]
# Received a frame at time [1756920002535415]
# Received a frame at time [1756920002569520]
# Received a frame at time [1756920002603625]
# Received a frame at time [1756920002637716]
# Received a frame at time [1756920002671807]
# Received a frame at time [1756920002705884]
# Received a frame at time [1756920002739961]
# Received a frame at time [1756920002774024]
# Received a frame at time [1756920002808087]
# Received a frame at time [1756920002842138]
# Received a frame at time [1756920002876188]
# Received a frame at time [1756920002910225]
# Received a frame at time [1756920002944262]
# Received a frame at time [1756920002978287]
# Received a frame at time [1756920003012312]
# Received a frame at time [1756920003046325]
# Received a frame at time [1756920003080338]
# Received a frame at time [1756920003114338]
# Received a frame at time [1756920003148338]
# Received a frame at time [1756920003182326]
# Received a frame at time [1756920003216315]
# Received a frame at time [1756920003250293]
# Received a frame at time [1756920003284271]
# Received a frame at time [1756920003318238]
# Received a frame at time [1756920003352205]
# Received a frame at time [1756920003386162]
# Received a frame at time [1756920003420119]
# Received a frame at time [1756920003454065]
# Received a frame at time [1756920003488011]
# Received a frame at time [1756920003521947]
# Received a frame at time [1756920003555883]
# Received a frame at time [1756920003589809]
# Received a frame at time [1756920003623736]
# Received a frame at time [1756920003657653]
# Received a frame at time [1756920003691570]
# Received a frame at time [1756920003725478]
# Received a frame at time [1756920003759386]
# Received a frame at time [1756920003793285]
# Received a frame at time [1756920003827184]
# Received a frame at time [1756920003861074]
# Received a frame at time [1756920003894964]
# Received a frame at time [1756920003928845]
# Received a frame at time [1756920003962726]
# Received a frame at time [1756920003996600]
# Received a frame at time [1756920004030473]
# Received a frame at time [1756920004064337]
# Received a frame at time [1756920004098201]
# Received a frame at time [1756920004132057]
# Received a frame at time [1756920004165913]
# Received a frame at time [1756920004199761]
# Received a frame at time [1756920004233609]
# Received a frame at time [1756920004267449]
# Received a frame at time [1756920004301289]
# Received a frame at time [1756920004335121]
# Received a frame at time [1756920004368954]
# Received a frame at time [1756920004402778]
# Received a frame at time [1756920004436602]
# Received a frame at time [1756920004470418]
# Received a frame at time [1756920004504234]
# Received a frame at time [1756920004538043]
# Received a frame at time [1756920004571852]
# Received a frame at time [1756920004605654]
# Received a frame at time [1756920004639456]
# Received a frame at time [1756920004673251]
# Received a frame at time [1756920004707046]
# Received a frame at time [1756920004740835]
# Received a frame at time [1756920004774623]
# Received a frame at time [1756920004808405]
# Received a frame at time [1756920004842187]
# Received a frame at time [1756920004875961]
# Received a frame at time [1756920004909735]
# Received a frame at time [1756920004943502]
# Received a frame at time [1756920004977269]
# Received a frame at time [1756920005011030]
# Received a frame at time [1756920005044791]
# Received a frame at time [1756920005078545]
# Received a frame at time [1756920005112299]
# Received a frame at time [1756920005146048]
# Received a frame at time [1756920005179796]
# Received a frame at time [1756920005213538]
# Received a frame at time [1756920005247280]
# Received a frame at time [1756920005281016]
# Received a frame at time [1756920005314752]
# Received a frame at time [1756920005348482]
# Received a frame at time [1756920005382212]
# Received a frame at time [1756920005415936]
# Received a frame at time [1756920005449660]
# Received a frame at time [1756920005483379]
# Received a frame at time [1756920005517099]
# Received a frame at time [1756920005550812]
# Received a frame at time [1756920005584525]
# Received a frame at time [1756920005618233]
# Received a frame at time [1756920005651941]
# Received a frame at time [1756920005685643]
# Received a frame at time [1756920005719345]
# Received a frame at time [1756920005753042]
# Received a frame at time [1756920005786739]
# Received a frame at time [1756920005820430]
# Received a frame at time [1756920005854121]
# Received a frame at time [1756920005887807]
# Received a frame at time [1756920005921492]
# Received a frame at time [1756920005955171]
# Received a frame at time [1756920005988850]
# Received a frame at time [1756920006022524]
# Received a frame at time [1756920006056198]
# Received a frame at time [1756920006089867]
# Received a frame at time [1756920006123536]
# Received a frame at time [1756920006157200]
# Received a frame at time [1756920006190864]
# Received a frame at time [1756920006224522]
# Received a frame at time [1756920006258181]
# Received a frame at time [1756920006291834]
# Received a frame at time [1756920006325487]
# Received a frame at time [1756920006359135]
# Received a frame at time [1756920006392783]
# Received a frame at time [1756920006426426]
# Received a frame at time [1756920006460069]
# Received a frame at time [1756920006493707]
# Received a frame at time [1756920006527345]
# Received a frame at time [1756920006560979]
# Received a frame at time [1756920006594613]
# Received a frame at time [1756920006628244]
# Received a frame at time [1756920006661874]
# Received a frame at time [1756920006695500]
# Received a frame at time [1756920006729126]
# Received a frame at time [1756920006762747]
# Received a frame at time [1756920006796368]
# Received a frame at time [1756920006829985]
# Received a frame at time [1756920006863602]
# Received a frame at time [1756920006897214]
# Received a frame at time [1756920006930826]
# Received a frame at time [1756920006964434]
# Received a frame at time [1756920006998043]
# Received a frame at time [1756920007031647]
# Received a frame at time [1756920007065251]
# Received a frame at time [1756920007098851]
# Received a frame at time [1756920007132451]
# Received a frame at time [1756920007166047]
# Received a frame at time [1756920007199643]
# Received a frame at time [1756920007233235]
# Received a frame at time [1756920007266827]
# Received a frame at time [1756920007300415]
# Received a frame at time [1756920007334003]
# Received a frame at time [1756920007367587]
# Received a frame at time [1756920007401172]
# Received a frame at time [1756920007434752]
# Received a frame at time [1756920007468332]
# Received a frame at time [1756920007501908]
# Received a frame at time [1756920007535484]
# Received a frame at time [1756920007569056]
# Received a frame at time [1756920007602628]
# Received a frame at time [1756920007636197]
# Received a frame at time [1756920007669766]
# Received a frame at time [1756920007703332]
# Received a frame at time [1756920007736898]
# Received a frame at time [1756920007770462]
# Received a frame at time [1756920007804025]
# Received a frame at time [1756920007837585]
# Received a frame at time [1756920007871145]
# Received a frame at time [1756920007904702]
# Received a frame at time [1756920007938259]
# Received a frame at time [1756920007971812]
# Received a frame at time [1756920008005365]
# Received a frame at time [1756920008038913]
# Received a frame at time [1756920008072461]
# Received a frame at time [1756920008106003]
# Received a frame at time [1756920008139546]
# Received a frame at time [1756920008173083]
# Received a frame at time [1756920008206620]
# Received a frame at time [1756920008240151]
# Received a frame at time [1756920008273682]
# Received a frame at time [1756920008307207]
# Received a frame at time [1756920008340732]
# Received a frame at time [1756920008374251]
# Received a frame at time [1756920008407770]
# Received a frame at time [1756920008441283]
# Received a frame at time [1756920008474796]
# Received a frame at time [1756920008508305]
# Received a frame at time [1756920008541813]
# Received a frame at time [1756920008575316]
# Received a frame at time [1756920008608819]
# Received a frame at time [1756920008642317]
# Received a frame at time [1756920008675815]
# Received a frame at time [1756920008709308]
# Received a frame at time [1756920008742801]
# Received a frame at time [1756920008776289]
# Received a frame at time [1756920008809777]
# Received a frame at time [1756920008843261]
# Received a frame at time [1756920008876746]
# Received a frame at time [1756920008910225]
# Received a frame at time [1756920008943704]
# Received a frame at time [1756920008977178]
# Received a frame at time [1756920009010652]
# Received a frame at time [1756920009044120]
# Received a frame at time [1756920009077588]
# Received a frame at time [1756920009111052]
# Received a frame at time [1756920009144516]
# Received a frame at time [1756920009177975]
# Received a frame at time [1756920009211434]
# Received a frame at time [1756920009244889]
# Received a frame at time [1756920009278343]
# Received a frame at time [1756920009311793]
# Received a frame at time [1756920009345243]
# Received a frame at time [1756920009378689]
# Received a frame at time [1756920009412135]
# Received a frame at time [1756920009445577]
# Received a frame at time [1756920009479019]
# Received a frame at time [1756920009512458]
# Received a frame at time [1756920009545897]
# Received a frame at time [1756920009579332]
# Received a frame at time [1756920009612768]
# Received a frame at time [1756920009646199]
# Received a frame at time [1756920009679630]
# Received a frame at time [1756920009713056]
# Received a frame at time [1756920009746482]
# Received a frame at time [1756920009779904]
# Received a frame at time [1756920009813326]
# Received a frame at time [1756920009846744]
# Received a frame at time [1756920009880162]
# Received a frame at time [1756920009913577]
# Received a frame at time [1756920009946992]
# Received a frame at time [1756920009980403]
# Received a frame at time [1756920010013815]
# Received a frame at time [1756920010047223]
# Received a frame at time [1756920010080631]
# Received a frame at time [1756920010114036]
# Received a frame at time [1756920010147441]
# Received a frame at time [1756920010180842]
# Received a frame at time [1756920010214243]
# Received a frame at time [1756920010247641]
# Received a frame at time [1756920010281039]
# Received a frame at time [1756920010314434]
# Received a frame at time [1756920010347830]
# Received a frame at time [1756920010381222]
# Received a frame at time [1756920010414614]
# Received a frame at time [1756920010448003]
# Received a frame at time [1756920010481392]
# Received a frame at time [1756920010514777]
# Received a frame at time [1756920010548162]
# Received a frame at time [1756920010581543]
# Received a frame at time [1756920010614924]
# Received a frame at time [1756920010648302]
# Received a frame at time [1756920010681680]
# Received a frame at time [1756920010715058]
# Received a frame at time [1756920010748435]
# Received a frame at time [1756920010781812]
# Received a frame at time [1756920010815189]
# Received a frame at time [1756920010848566]
# Received a frame at time [1756920010881942]
# Received a frame at time [1756920010915318]
# Received a frame at time [1756920010948693]
# Received a frame at time [1756920010982068]
# Received a frame at time [1756920011015442]
# Received a frame at time [1756920011048816]
# Received a frame at time [1756920011082189]
# Received a frame at time [1756920011115563]
# Received a frame at time [1756920011148935]
# Received a frame at time [1756920011182307]
# Received a frame at time [1756920011215678]
# Received a frame at time [1756920011249049]
# Received a frame at time [1756920011282419]
# Received a frame at time [1756920011315789]
# Received a frame at time [1756920011349158]
# Received a frame at time [1756920011382527]
# Received a frame at time [1756920011415895]
# Received a frame at time [1756920011449263]
# Received a frame at time [1756920011482631]
# Received a frame at time [1756920011515998]
# Received a frame at time [1756920011549364]
# Received a frame at time [1756920011582730]
# Received a frame at time [1756920011616095]
# Received a frame at time [1756920011649460]
# Received a frame at time [1756920011682824]
# Received a frame at time [1756920011716188]
# Received a frame at time [1756920011749552]
# Received a frame at time [1756920011782914]
# Received a frame at time [1756920011816276]
# Received a frame at time [1756920011849639]
# Received a frame at time [1756920011883000]
# Received a frame at time [1756920011916361]
# Received a frame at time [1756920011949721]
# Received a frame at time [1756920011983081]
# Received a frame at time [1756920012016440]
# Received a frame at time [1756920012049799]
# Received a frame at time [1756920012083157]
# Received a frame at time [1756920012116515]
# Received a frame at time [1756920012149874]
# Received a frame at time [1756920012183231]
# Received a frame at time [1756920012216588]
# Received a frame at time [1756920012249944]
# Received a frame at time [1756920012283300]
# Received a frame at time [1756920012316655]
# Received a frame at time [1756920012350010]
# Received a frame at time [1756920012383364]
# Received a frame at time [1756920012416718]
# Received a frame at time [1756920012450071]
# Received a frame at time [1756920012483425]
# Received a frame at time [1756920012516777]
# Received a frame at time [1756920012550129]
# Received a frame at time [1756920012583480]
# Received a frame at time [1756920012616831]
# Received a frame at time [1756920012650181]
# Received a frame at time [1756920012683531]
# Received a frame at time [1756920012716880]
# Received a frame at time [1756920012750229]
# Received a frame at time [1756920012783577]
# Received a frame at time [1756920012816925]
# Received a frame at time [1756920012850272]
# Received a frame at time [1756920012883619]
# Received a frame at time [1756920012916965]
# Received a frame at time [1756920012950311]
# Received a frame at time [1756920012983657]
# Received a frame at time [1756920013017003]
# Received a frame at time [1756920013050346]
# Received a frame at time [1756920013083690]
# Received a frame at time [1756920013117033]
# Received a frame at time [1756920013150376]
# Received a frame at time [1756920013183718]
# Received a frame at time [1756920013217060]
# Received a frame at time [1756920013250401]
# Received a frame at time [1756920013283742]
# Received a frame at time [1756920013317082]
# Received a frame at time [1756920013350423]
# Received a frame at time [1756920013383762]
# Received a frame at time [1756920013417101]
# Received a frame at time [1756920013450439]
# Received a frame at time [1756920013483777]
# Received a frame at time [1756920013517114]
# Received a frame at time [1756920013550451]
# Received a frame at time [1756920013583787]
# Received a frame at time [1756920013617123]
# Received a frame at time [1756920013650458]
# Received a frame at time [1756920013683793]
# Received a frame at time [1756920013717128]
# Received a frame at time [1756920013750462]
# Received a frame at time [1756920013783795]
# Received a frame at time [1756920013817128]
# Received a frame at time [1756920013850460]
# Received a frame at time [1756920013883792]
# Received a frame at time [1756920013917123]
# Received a frame at time [1756920013950454]
# Received a frame at time [1756920013983784]
# Received a frame at time [1756920014017114]
# Received a frame at time [1756920014050444]
# Received a frame at time [1756920014083773]
# Received a frame at time [1756920014117101]
# Received a frame at time [1756920014150429]
# Received a frame at time [1756920014183756]
# Received a frame at time [1756920014217083]
# Received a frame at time [1756920014250409]
# Received a frame at time [1756920014283735]
# Received a frame at time [1756920014317060]
# Received a frame at time [1756920014350385]
# Received a frame at time [1756920014383709]
# Received a frame at time [1756920014417033]
# Received a frame at time [1756920014450357]
# Received a frame at time [1756920014483680]
# Received a frame at time [1756920014517002]
# Received a frame at time [1756920014550324]
# Received a frame at time [1756920014583645]
# Received a frame at time [1756920014616966]
# Received a frame at time [1756920014650286]
# Received a frame at time [1756920014683606]
# Received a frame at time [1756920014716925]
# Received a frame at time [1756920014750244]
# Received a frame at time [1756920014783562]
# Received a frame at time [1756920014816881]
# Received a frame at time [1756920014850198]
# Received a frame at time [1756920014883515]
# Received a frame at time [1756920014916831]
# Received a frame at time [1756920014950147]
# Received a frame at time [1756920014983462]
# Received a frame at time [1756920015016777]
# Received a frame at time [1756920015050091]
# Received a frame at time [1756920015083405]
# Received a frame at time [1756920015116718]
# Received a frame at time [1756920015150031]
# Received a frame at time [1756920015183344]
# Received a frame at time [1756920015216656]
# Received a frame at time [1756920015249967]
# Received a frame at time [1756920015283278]
# Received a frame at time [1756920015316588]
# Received a frame at time [1756920015349898]
# Received a frame at time [1756920015383207]
# Received a frame at time [1756920015416516]
# Received a frame at time [1756920015449824]
# Received a frame at time [1756920015483132]
# Received a frame at time [1756920015516439]
# Received a frame at time [1756920015549746]
# Received a frame at time [1756920015583053]
# Received a frame at time [1756920015616359]
# Received a frame at time [1756920015649664]
# Received a frame at time [1756920015682969]
# Received a frame at time [1756920015716273]
# Received a frame at time [1756920015749577]
# Received a frame at time [1756920015782880]
# Received a frame at time [1756920015816183]
# Received a frame at time [1756920015849485]
# Received a frame at time [1756920015882787]
# Received a frame at time [1756920015916088]
# Received a frame at time [1756920015949390]
# Received a frame at time [1756920015982690]
# Received a frame at time [1756920016015990]
# Received a frame at time [1756920016049289]
# Received a frame at time [1756920016082588]
# Received a frame at time [1756920016115886]
# Received a frame at time [1756920016149184]
# Received a frame at time [1756920016182481]
# Received a frame at time [1756920016215778]
# Received a frame at time [1756920016249074]
# Received a frame at time [1756920016282370]
# Received a frame at time [1756920016315666]
# Received a frame at time [1756920016348961]
# Received a frame at time [1756920016382255]
# Received a frame at time [1756920016415549]
# Received a frame at time [1756920016448842]
# Received a frame at time [1756920016482135]
# Received a frame at time [1756920016515427]
# Received a frame at time [1756920016548719]
# Received a frame at time [1756920016582010]
# Received a frame at time [1756920016615301]
# Received a frame at time [1756920016648591]
# Received a frame at time [1756920016681882]
# Received a frame at time [1756920016715171]
# Received a frame at time [1756920016748460]
# Received a frame at time [1756920016781748]
# Received a frame at time [1756920016815036]
# Received a frame at time [1756920016848323]
# Received a frame at time [1756920016881610]
# Received a frame at time [1756920016914896]
# Received a frame at time [1756920016948182]
# Received a frame at time [1756920016981467]
# Received a frame at time [1756920017014752]
# Received a frame at time [1756920017048037]
# Received a frame at time [1756920017081321]
# Received a frame at time [1756920017114604]
# Received a frame at time [1756920017147887]
# Received a frame at time [1756920017181169]
# Received a frame at time [1756920017214451]
# Received a frame at time [1756920017247732]
# Received a frame at time [1756920017281013]
# Received a frame at time [1756920017314293]
# Received a frame at time [1756920017347573]
# Received a frame at time [1756920017380852]
# Received a frame at time [1756920017414132]
# Received a frame at time [1756920017447410]
# Received a frame at time [1756920017480688]
# Received a frame at time [1756920017513965]
# Received a frame at time [1756920017547242]
# Received a frame at time [1756920017580518]
# Received a frame at time [1756920017613794]
# Received a frame at time [1756920017647069]
# Received a frame at time [1756920017680344]
# Received a frame at time [1756920017713618]
# Received a frame at time [1756920017746892]
# Received a frame at time [1756920017780166]
# Received a frame at time [1756920017813439]
# Received a frame at time [1756920017846711]
# Received a frame at time [1756920017879983]
# Received a frame at time [1756920017913254]
# Received a frame at time [1756920017946525]
# Received a frame at time [1756920017979795]
# Received a frame at time [1756920018013065]
# Received a frame at time [1756920018046334]
# Received a frame at time [1756920018079603]
# Received a frame at time [1756920018112871]
# Received a frame at time [1756920018146140]
# Received a frame at time [1756920018179407]
# Received a frame at time [1756920018212674]
# Received a frame at time [1756920018245940]
# Received a frame at time [1756920018279206]
# Received a frame at time [1756920018312471]
# Received a frame at time [1756920018345736]
# Received a frame at time [1756920018379000]
# Received a frame at time [1756920018412264]
# Received a frame at time [1756920018445527]
# Received a frame at time [1756920018478790]
# Received a frame at time [1756920018512052]
# Received a frame at time [1756920018545315]
# Received a frame at time [1756920018578576]
# Received a frame at time [1756920018611837]
# Received a frame at time [1756920018645097]
# Received a frame at time [1756920018678357]
# Received a frame at time [1756920018711616]
# Received a frame at time [1756920018744875]
# Received a frame at time [1756920018778133]
# Received a frame at time [1756920018811391]
# Received a frame at time [1756920018844648]
# Received a frame at time [1756920018877905]
# Received a frame at time [1756920018911162]
# Received a frame at time [1756920018944418]
# Received a frame at time [1756920018977673]
# Received a frame at time [1756920019010928]
# Received a frame at time [1756920019044182]
# Received a frame at time [1756920019077436]
# Received a frame at time [1756920019110689]
# Received a frame at time [1756920019143942]
# Received a frame at time [1756920019177194]
# Received a frame at time [1756920019210446]
# Received a frame at time [1756920019243697]
# Received a frame at time [1756920019276949]
# Received a frame at time [1756920019310199]
# Received a frame at time [1756920019343449]
# Received a frame at time [1756920019376698]
# Received a frame at time [1756920019409947]
# Received a frame at time [1756920019443195]
# Received a frame at time [1756920019476443]
# Received a frame at time [1756920019509690]
# Received a frame at time [1756920019542937]
# Received a frame at time [1756920019576183]
# Received a frame at time [1756920019609429]
# Received a frame at time [1756920019642675]
# Received a frame at time [1756920019675920]
# Received a frame at time [1756920019709164]
# Received a frame at time [1756920019742408]
# Received a frame at time [1756920019775651]
# Received a frame at time [1756920019808894]
# Received a frame at time [1756920019842136]
# Received a frame at time [1756920019875378]
# Received a frame at time [1756920019908619]
# Received a frame at time [1756920019941860]
# Received a frame at time [1756920019975100]
# Received a frame at time [1756920020008341]
# Received a frame at time [1756920020041580]
# Received a frame at time [1756920020074819]
# Received a frame at time [1756920020108057]
# Received a frame at time [1756920020141295]
# Received a frame at time [1756920020174532]
# Received a frame at time [1756920020207769]
# Received a frame at time [1756920020241005]
# Received a frame at time [1756920020274241]
# Received a frame at time [1756920020307476]
# Received a frame at time [1756920020340711]
# Received a frame at time [1756920020373946]
# Received a frame at time [1756920020407180]
# Received a frame at time [1756920020440413]
# Received a frame at time [1756920020473646]
# Received a frame at time [1756920020506878]
# Received a frame at time [1756920020540110]
# Received a frame at time [1756920020573341]
# Received a frame at time [1756920020606572]
# Received a frame at time [1756920020639802]
# Received a frame at time [1756920020673032]
# Received a frame at time [1756920020706261]
# Received a frame at time [1756920020739490]
# Received a frame at time [1756920020772719]
# Received a frame at time [1756920020805947]
# Received a frame at time [1756920020839175]
# Received a frame at time [1756920020872403]
# Received a frame at time [1756920020905631]
# Received a frame at time [1756920020938859]
# Received a frame at time [1756920020972087]
# Received a frame at time [1756920021005315]
# Received a frame at time [1756920021038542]
# Received a frame at time [1756920021071769]
# Received a frame at time [1756920021104996]
# Received a frame at time [1756920021138224]
# Received a frame at time [1756920021171451]
# Received a frame at time [1756920021204678]
# Received a frame at time [1756920021237905]
# Received a frame at time [1756920021271132]
# Received a frame at time [1756920021304359]
# Received a frame at time [1756920021337586]
# Received a frame at time [1756920021370813]
# Received a frame at time [1756920021404040]
# Received a frame at time [1756920021437267]
# Received a frame at time [1756920021470494]
# Received a frame at time [1756920021503721]
# Received a frame at time [1756920021536949]
# Received a frame at time [1756920021570176]
# Received a frame at time [1756920021603403]
# Received a frame at time [1756920021636630]
# Received a frame at time [1756920021669857]
# Received a frame at time [1756920021703084]
# Received a frame at time [1756920021736311]
# Received a frame at time [1756920021769538]
# Received a frame at time [1756920021802765]
# Received a frame at time [1756920021835992]
# Received a frame at time [1756920021869219]
# Received a frame at time [1756920021902446]
# Received a frame at time [1756920021935674]
# Received a frame at time [1756920021968901]
# Received a frame at time [1756920022002128]
# Received a frame at time [1756920022035355]
# Received a frame at time [1756920022068582]
# Received a frame at time [1756920022101809]
# Received a frame at time [1756920022135036]
# Received a frame at time [1756920022168263]
# Received a frame at time [1756920022201490]
# Received a frame at time [1756920022234717]
# Received a frame at time [1756920022267944]
# Received a frame at time [1756920022301171]
# Received a frame at time [1756920022334399]
# Received a frame at time [1756920022367626]
# Received a frame at time [1756920022400853]
# Received a frame at time [1756920022434080]
# Received a frame at time [1756920022467307]
# Received a frame at time [1756920022500534]
# Received a frame at time [1756920022533761]
# Received a frame at time [1756920022566988]
# Received a frame at time [1756920022600215]
# Received a frame at time [1756920022633442]
# Received a frame at time [1756920022666669]
# Received a frame at time [1756920022699897]
# Received a frame at time [1756920022733124]
# Received a frame at time [1756920022766351]
# Received a frame at time [1756920022799578]
# Received a frame at time [1756920022832805]
# Received a frame at time [1756920022866032]
# Received a frame at time [1756920022899259]
# Received a frame at time [1756920022932486]
# Received a frame at time [1756920022965713]
# Received a frame at time [1756920022998940]
# Received a frame at time [1756920023032167]
# Received a frame at time [1756920023065394]
# Received a frame at time [1756920023098621]
# Received a frame at time [1756920023131849]
# Received a frame at time [1756920023165076]
# Received a frame at time [1756920023198303]
# Received a frame at time [1756920023231530]
# Received a frame at time [1756920023264757]
# Received a frame at time [1756920023297984]
# Received a frame at time [1756920023331211]
# Received a frame at time [1756920023364438]
# Received a frame at time [1756920023397665]
# Received a frame at time [1756920023430892]
# Received a frame at time [1756920023464119]
# Received a frame at time [1756920023497346]
# Received a frame at time [1756920023530574]
# Received a frame at time [1756920023563801]
# Received a frame at time [1756920023597028]
# Received a frame at time [1756920023630255]
# Received a frame at time [1756920023663482]
# Received a frame at time [1756920023696709]
# Received a frame at time [1756920023729936]
# Received a frame at time [1756920023763163]
# Received a frame at time [1756920023796390]
# Received a frame at time [1756920023829617]
# Received a frame at time [1756920023862844]
# Received a frame at time [1756920023896071]
# Received a frame at time [1756920023929299]
# Received a frame at time [1756920023962526]
# Received a frame at time [1756920023995753]
# Received a frame at time [1756920024028980]
# Received a frame at time [1756920024062207]
# Received a frame at time [1756920024095434]
# Received a frame at time [1756920024128661]
# Received a frame at time [1756920024161888]
# Received a frame at time [1756920024195114]
# Received a frame at time [1756920024228340]
# Received a frame at time [1756920024261565]
# Received a frame at time [1756920024294791]
# Received a frame at time [1756920024328015]
# Received a frame at time [1756920024361239]
# Received a frame at time [1756920024394462]
# Received a frame at time [1756920024427685]
# Received a frame at time [1756920024460908]
# Received a frame at time [1756920024494131]
# Received a frame at time [1756920024527354]
# Received a frame at time [1756920024560577]
# Received a frame at time [1756920024593800]
# Received a frame at time [1756920024627023]
# Received a frame at time [1756920024660247]
# Received a frame at time [1756920024693470]
# Received a frame at time [1756920024726693]
# Received a frame at time [1756920024759916]
# Received a frame at time [1756920024793139]
# Received a frame at time [1756920024826362]
# Received a frame at time [1756920024859585]
# Received a frame at time [1756920024892808]
# Received a frame at time [1756920024926031]
# Received a frame at time [1756920024959254]
# Received a frame at time [1756920024992477]
# Received a frame at time [1756920025025701]
# Received a frame at time [1756920025058924]
# Received a frame at time [1756920025092147]
# Received a frame at time [1756920025125370]
# Received a frame at time [1756920025158593]
# Received a frame at time [1756920025191816]
# Received a frame at time [1756920025225039]
# Received a frame at time [1756920025258262]
# Received a frame at time [1756920025291485]
# Received a frame at time [1756920025324708]
# Received a frame at time [1756920025357931]
# Received a frame at time [1756920025391155]
# Received a frame at time [1756920025424378]
# Received a frame at time [1756920025457601]
# Received a frame at time [1756920025490824]
# Received a frame at time [1756920025524047]
# Received a frame at time [1756920025557270]
# Received a frame at time [1756920025590493]
# Received a frame at time [1756920025623716]
# Received a frame at time [1756920025656939]
# Received a frame at time [1756920025690162]
# Received a frame at time [1756920025723386]
# Received a frame at time [1756920025756609]
# Received a frame at time [1756920025789832]
# Received a frame at time [1756920025823055]
# Received a frame at time [1756920025856277]
# Received a frame at time [1756920025889499]
# Received a frame at time [1756920025922720]
# Received a frame at time [1756920025955941]
# Received a frame at time [1756920025989161]
# Received a frame at time [1756920026022381]
# Received a frame at time [1756920026055600]
# Received a frame at time [1756920026088820]
# Received a frame at time [1756920026122038]
# Received a frame at time [1756920026155256]
# Received a frame at time [1756920026188473]
# Received a frame at time [1756920026221690]
# Received a frame at time [1756920026254906]
# Received a frame at time [1756920026288122]
# Received a frame at time [1756920026321337]
# Received a frame at time [1756920026354552]
# Received a frame at time [1756920026387766]
# Received a frame at time [1756920026420980]
# Received a frame at time [1756920026454193]
# Received a frame at time [1756920026487407]
# Received a frame at time [1756920026520619]
# Received a frame at time [1756920026553831]
# Received a frame at time [1756920026587042]
# Received a frame at time [1756920026620253]
# Received a frame at time [1756920026653463]
# Received a frame at time [1756920026686673]
# Received a frame at time [1756920026719882]
# Received a frame at time [1756920026753091]
# Received a frame at time [1756920026786299]
# Received a frame at time [1756920026819507]
# Received a frame at time [1756920026852715]
# Received a frame at time [1756920026885922]
# Received a frame at time [1756920026919128]
# Received a frame at time [1756920026952334]
# Received a frame at time [1756920026985539]
# Received a frame at time [1756920027018744]
# Received a frame at time [1756920027051948]
# Received a frame at time [1756920027085152]
# Received a frame at time [1756920027118355]
# Received a frame at time [1756920027151558]
# Received a frame at time [1756920027184760]
# Received a frame at time [1756920027217963]
# Received a frame at time [1756920027251164]
# Received a frame at time [1756920027284365]
# Received a frame at time [1756920027317565]
# Received a frame at time [1756920027350765]
# Received a frame at time [1756920027383964]
# Received a frame at time [1756920027417163]
# Received a frame at time [1756920027450361]
# Received a frame at time [1756920027483560]
# Received a frame at time [1756920027516756]
# Received a frame at time [1756920027549953]
# Received a frame at time [1756920027583150]
# Received a frame at time [1756920027616346]
# Received a frame at time [1756920027649541]
# Received a frame at time [1756920027682736]
# Received a frame at time [1756920027715930]
# Received a frame at time [1756920027749124]
# Received a frame at time [1756920027782317]
# Received a frame at time [1756920027815510]
# Received a frame at time [1756920027848702]
# Received a frame at time [1756920027881894]
# Received a frame at time [1756920027915085]
# Received a frame at time [1756920027948277]
# Received a frame at time [1756920027981467]
# Received a frame at time [1756920028014657]
# Received a frame at time [1756920028047846]
# Received a frame at time [1756920028081035]
# Received a frame at time [1756920028114223]
# Received a frame at time [1756920028147411]
# Received a frame at time [1756920028180598]
# Received a frame at time [1756920028213785]
# Received a frame at time [1756920028246971]
# Received a frame at time [1756920028280157]
# Received a frame at time [1756920028313343]
# Received a frame at time [1756920028346528]
# Received a frame at time [1756920028379712]
# Received a frame at time [1756920028412896]
# Received a frame at time [1756920028446079]
# Received a frame at time [1756920028479262]
# Received a frame at time [1756920028512444]
# Received a frame at time [1756920028545626]
# Received a frame at time [1756920028578807]
# Received a frame at time [1756920028611988]
# Received a frame at time [1756920028645168]
# Received a frame at time [1756920028678349]
# Received a frame at time [1756920028711528]
# Received a frame at time [1756920028744707]
# Received a frame at time [1756920028777885]
# Received a frame at time [1756920028811063]
# Received a frame at time [1756920028844240]
# Received a frame at time [1756920028877417]
# Received a frame at time [1756920028910593]
# Received a frame at time [1756920028943769]
# Received a frame at time [1756920028976944]
# Received a frame at time [1756920029010119]
# Received a frame at time [1756920029043293]
# Received a frame at time [1756920029076468]
# Received a frame at time [1756920029109641]
# Received a frame at time [1756920029142814]
# Received a frame at time [1756920029175986]
# Received a frame at time [1756920029209158]
# Received a frame at time [1756920029242329]
# Received a frame at time [1756920029275500]
# Received a frame at time [1756920029308670]
# Received a frame at time [1756920029341840]
# Received a frame at time [1756920029375009]
# Received a frame at time [1756920029408178]
# Received a frame at time [1756920029441347]
# Received a frame at time [1756920029474515]
# Received a frame at time [1756920029507682]
# Received a frame at time [1756920029540849]
# Received a frame at time [1756920029574015]
# Received a frame at time [1756920029607181]
# Received a frame at time [1756920029640346]
# Received a frame at time [1756920029673511]
# Received a frame at time [1756920029706675]
# Received a frame at time [1756920029739839]
# Received a frame at time [1756920029773002]
# Received a frame at time [1756920029806166]
# Received a frame at time [1756920029839328]
# Received a frame at time [1756920029872490]
# Received a frame at time [1756920029905651]
# Received a frame at time [1756920029938812]
# Received a frame at time [1756920029971972]
# Received a frame at time [1756920030005132]
# Received a frame at time [1756920030038291]
# Received a frame at time [1756920030071450]
# Received a frame at time [1756920030104608]
# Received a frame at time [1756920030137766]
# Received a frame at time [1756920030170924]
# Received a frame at time [1756920030204081]
# Received a frame at time [1756920030237237]
# Received a frame at time [1756920030270393]
# Received a frame at time [1756920030303548]
# Received a frame at time [1756920030336703]
# Received a frame at time [1756920030369857]
# Received a frame at time [1756920030403011]
# Received a frame at time [1756920030436164]
# Received a frame at time [1756920030469317]
# Received a frame at time [1756920030502469]
# Received a frame at time [1756920030535622]
# Received a frame at time [1756920030568773]
# Received a frame at time [1756920030601924]
# Received a frame at time [1756920030635074]
# Received a frame at time [1756920030668224]
# Received a frame at time [1756920030701373]
# Received a frame at time [1756920030734522]
# Received a frame at time [1756920030767670]
# Received a frame at time [1756920030800818]
# Received a frame at time [1756920030833965]
# Received a frame at time [1756920030867112]
# Received a frame at time [1756920030900259]
# Received a frame at time [1756920030933405]
# Received a frame at time [1756920030966550]
# Received a frame at time [1756920030999695]
# Received a frame at time [1756920031032839]
# Received a frame at time [1756920031065983]
# Received a frame at time [1756920031099126]
# Received a frame at time [1756920031132269]
# Received a frame at time [1756920031165411]
# Received a frame at time [1756920031198553]
# Received a frame at time [1756920031231694]
# Received a frame at time [1756920031264836]
# Received a frame at time [1756920031297976]
# Received a frame at time [1756920031331116]
# Received a frame at time [1756920031364255]
# Received a frame at time [1756920031397394]
# Received a frame at time [1756920031430532]
# Received a frame at time [1756920031463670]
# Received a frame at time [1756920031496807]
# Received a frame at time [1756920031529945]
# Received a frame at time [1756920031563080]
# Received a frame at time [1756920031596217]
# Received a frame at time [1756920031629351]
# Received a frame at time [1756920031662487]
# Received a frame at time [1756920031695621]
# Received a frame at time [1756920031728755]
# Received a frame at time [1756920031761888]
# Received a frame at time [1756920031795021]
# Received a frame at time [1756920031828153]
# Received a frame at time [1756920031861285]
# Received a frame at time [1756920031894416]
# Received a frame at time [1756920031927547]
# Received a frame at time [1756920031960677]
# Received a frame at time [1756920031993807]
# Received a frame at time [1756920032026937]
# Received a frame at time [1756920032060066]
# Received a frame at time [1756920032093194]
# Received a frame at time [1756920032126322]
# Received a frame at time [1756920032159449]
# Received a frame at time [1756920032192576]
# Received a frame at time [1756920032225702]
# Received a frame at time [1756920032258828]
# Received a frame at time [1756920032291953]
# Received a frame at time [1756920032325078]
# Received a frame at time [1756920032358202]
# Received a frame at time [1756920032391327]
# Received a frame at time [1756920032424450]
# Received a frame at time [1756920032457573]
# Received a frame at time [1756920032490695]
# Received a frame at time [1756920032523817]
# Received a frame at time [1756920032556938]
# Received a frame at time [1756920032590059]
# Received a frame at time [1756920032623179]
# Received a frame at time [1756920032656299]
# Received a frame at time [1756920032689418]
# Received a frame at time [1756920032722537]
# Received a frame at time [1756920032755656]
# Received a frame at time [1756920032788774]
# Received a frame at time [1756920032821891]
# Received a frame at time [1756920032855008]
# Received a frame at time [1756920032888124]
# Received a frame at time [1756920032921240]
# Received a frame at time [1756920032954355]
# Received a frame at time [1756920032987470]
# Received a frame at time [1756920033020584]
# Received a frame at time [1756920033053698]
# Received a frame at time [1756920033086811]
# Received a frame at time [1756920033119925]
# Received a frame at time [1756920033153037]
# Received a frame at time [1756920033186149]
# Received a frame at time [1756920033219260]
# Received a frame at time [1756920033252371]
# Received a frame at time [1756920033285481]
# Received a frame at time [1756920033318591]
# Received a frame at time [1756920033351700]
# Received a frame at time [1756920033384809]
# Received a frame at time [1756920033417918]
# Received a frame at time [1756920033451027]
# Received a frame at time [1756920033484137]
# Received a frame at time [1756920033517248]
# Received a frame at time [1756920033550359]
# Received a frame at time [1756920033583474]
# Received a frame at time [1756920033616589]
# Received a frame at time [1756920033649711]
# Received a frame at time [1756920033682833]
# Received a frame at time [1756920033715966]
# Received a frame at time [1756920033749099]
# Received a frame at time [1756920033782247]
# Received a frame at time [1756920033815395]
# Received a frame at time [1756920033848567]
# Received a frame at time [1756920033881738]
# Received a frame at time [1756920033914940]
# Received a frame at time [1756920033948142]
# Received a frame at time [1756920033981379]
# Received a frame at time [1756920034014616]
# Received a frame at time [1756920034047887]
# Received a frame at time [1756920034081158]
# Received a frame at time [1756920034114463]
# Received a frame at time [1756920034147768]
# Received a frame at time [1756920034181106]
# Received a frame at time [1756920034214444]
# Received a frame at time [1756920034247812]
# Received a frame at time [1756920034281179]
# Received a frame at time [1756920034314571]
# Received a frame at time [1756920034347963]
# Received a frame at time [1756920034381380]
# Received a frame at time [1756920034414797]
# Received a frame at time [1756920034448241]
# Received a frame at time [1756920034481685]
# Received a frame at time [1756920034515163]
# Received a frame at time [1756920034548641]
# Received a frame at time [1756920034582161]
# Received a frame at time [1756920034615682]
# Received a frame at time [1756920034649253]
# Received a frame at time [1756920034682824]
# Received a frame at time [1756920034716450]
# Received a frame at time [1756920034750076]
# Received a frame at time [1756920034783762]
# Received a frame at time [1756920034817448]
# Received a frame at time [1756920034851208]
# Received a frame at time [1756920034884968]
# Received a frame at time [1756920034918859]
# Received a frame at time [1756920034952750]
# Received a frame at time [1756920034986840]
# Received a frame at time [1756920035020929]
# Received a frame at time [1756920035055021]
# Received a frame at time [1756920035089113]
# Received a frame at time [1756920035125592]
# Received a frame at time [1756920035162071]
# Received a frame at time [1756920035200988]
# Received a frame at time [1756920035239905]
# Received a frame at time [1756920035281403]
# Received a frame at time [1756920035322903]
# Received a frame at time [1756920035369472]
# Received a frame at time [1756920035416040]
# Received a frame at time [1756920035469676]
# Received a frame at time [1756920035523312]
# Received a frame at time [1756920035584174]
# Received a frame at time [1756920035645034]
# Received a frame at time [1756920035712977]
# Received a frame at time [1756920035780918]
# Received a frame at time [1756920035856090]
# Received a frame at time [1756920035931262]
# Received a frame at time [1756920036013664]
# Received a frame at time [1756920036096067]
# Received a frame at time [1756920036185699]
# Received a frame at time [1756920036275331]
# Received a frame at time [1756920036368537]
# Received a frame at time [1756920036461742]
# Received a frame at time [1756920036551572]
# Received a frame at time [1756920036641403]
# Received a frame at time [1756920036727549]
# Received a frame at time [1756920036813695]
# Received a frame at time [1756920036896972]
# Received a frame at time [1756920036980249]
# Received a frame at time [1756920037060917]
# Received a frame at time [1756920037141586]
# Received a frame at time [1756920037220202]
# Received a frame at time [1756920037298818]
# Received a frame at time [1756920037375501]
# Received a frame at time [1756920037452184]
# Received a frame at time [1756920037526987]
# Received a frame at time [1756920037601790]
# Received a frame at time [1756920037674798]
# Received a frame at time [1756920037747806]
# Received a frame at time [1756920037819114]
# Received a frame at time [1756920037890423]
# Received a frame at time [1756920037960147]
# Received a frame at time [1756920038029871]
# Received a frame at time [1756920038098126]
# Received a frame at time [1756920038166381]
# Received a frame at time [1756920038233260]
# Received a frame at time [1756920038300139]
# Received a frame at time [1756920038365724]
# Received a frame at time [1756920038431309]
# Received a frame at time [1756920038495676]
# Received a frame at time [1756920038560043]
# Received a frame at time [1756920038623264]
# Received a frame at time [1756920038686484]
# Received a frame at time [1756920038748604]
# Received a frame at time [1756920038810724]
# Received a frame at time [1756920038871741]
# Received a frame at time [1756920038932758]
# Received a frame at time [1756920038992875]
# Received a frame at time [1756920039052992]
# Received a frame at time [1756920039112298]
# Received a frame at time [1756920039171604]
# Received a frame at time [1756920039230144]
# Received a frame at time [1756920039288685]
# Received a frame at time [1756920039346501]
# Received a frame at time [1756920039404317]
# Received a frame at time [1756920039461444]
# Received a frame at time [1756920039518571]
# Received a frame at time [1756920039575046]
# Received a frame at time [1756920039631521]
# Received a frame at time [1756920039687370]
# Received a frame at time [1756920039743219]
# Received a frame at time [1756920039798465]
# Received a frame at time [1756920039853712]
# Received a frame at time [1756920039908381]
# Received a frame at time [1756920039963050]
# Received a frame at time [1756920040017169]
# Received a frame at time [1756920040071288]
# Received a frame at time [1756920040124875]
# Received a frame at time [1756920040178462]
# Received a frame at time [1756920040231536]
# Received a frame at time [1756920040284610]
# Received a frame at time [1756920040337192]
# Received a frame at time [1756920040389774]
# Received a frame at time [1756920040441878]
# Received a frame at time [1756920040493981]
# Received a frame at time [1756920040545625]
# Received a frame at time [1756920040597269]
# Received a frame at time [1756920040648469]
# Received a frame at time [1756920040699669]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 23
#      21     # Show a preview of the image
#      22     cv.imshow("Preview", frame.image)
# ---> 23 cv.waitKey(2)
#
# KeyboardInterrupt:

# %% [markdown]
# ## MultiStreamSlicer

# %%
from datetime import timedelta

import cv2 as cv
import dv_processing as dv

# Open the camera, just use first detected DAVIS camera
camera = dv.io.camera.DAVIS()

# Set ROI area
#camera.setCropArea((50, 5, 255, 255))

# Initialize a multi-stream slicer
slicer = dv.EventMultiStreamSlicer("events")

# Add a frame stream to the slicer
slicer.addFrameStream("frames")

# Initialize a visualizer for the overlay
visualizer = dv.visualization.EventVisualizer(camera.getEventResolution(), dv.visualization.colors.white(),
                                              dv.visualization.colors.green(), dv.visualization.colors.red())

# Create a window for image display
cv.namedWindow("Preview", cv.WINDOW_NORMAL)


# Callback method for time based slicing
def display_preview(data):
    # Retrieve frame data using the named method and stream name
    frames = data.getFrames("frames")

    # Retrieve event data
    events = data.getEvents("events")

    # Retrieve and color convert the latest frame of retrieved frames
    latest_image = None
    if len(frames) > 0:
        if len(frames[-1].image.shape) == 3:
            # We already have colored image, no conversion
            latest_image = frames[-1].image
        else:
            # Image is grayscale, convert to color (BGR image)
            latest_image = cv.cvtColor(frames[-1].image, cv.COLOR_GRAY2BGR)
    else:
        return

    # Generate a preview and show the final image
    cv.imshow("Preview", visualizer.generateImage(events, latest_image))

    # If escape button is pressed (code 27 is escape key), exit the program cleanly
    if cv.waitKey(2) == 27:
        exit(0)


# Register a job to be performed every 33 milliseconds
slicer.doEveryTimeInterval(timedelta(milliseconds=10), display_preview)

# Continue the loop while both cameras are connected
while camera.isRunning():
    events = camera.getNextEventBatch()
    if events is not None:
        slicer.accept("events", events)

    frame = camera.getNextFrame()
    if frame is not None:
        slicer.accept("frames", [frame])

# %%
# !pip install dv-processing
# Out:
# Collecting dv-processing
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [25 lines of output]
#   Using git hash
#   Traceback (most recent call last):
#     File "C:\ProgramData\Lucid Vision Labs\ArenaView\ArenaPy\Miniconda3\envs\lucid_env\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 351, in <module>
#       main()
#     File "C:\ProgramData\Lucid Vision Labs\ArenaView\ArenaPy\Miniconda3\envs\lucid_env\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 333, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "C:\ProgramData\Lucid Vision Labs\ArenaView\ArenaPy\Miniconda3\envs\lucid_env\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 118, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "C:\Users\bermude8\AppData\Local\Temp\pip-build-env-67lwr3z8\overlay\Lib\site-packages\setuptools\build_meta.py", line 341, in get_requires_for_build_wheel
#       return self._get_build_requires(config_settings, requirements=['wheel'])
#     File "C:\Users\bermude8\AppData\Local\Temp\pip-build-env-67lwr3z8\overlay\Lib\site-packages\setuptools\build_meta.py", line 323, in _get_build_requires
#       self.run_setup()
#     File "C:\Users\bermude8\AppData\Local\Temp\pip-build-env-67lwr3z8\overlay\Lib\site-packages\setuptools\build_meta.py", line 338, in run_setup
#       exec(code, locals())
#     File "<string>", line 208, in <module>
#     File "<string>", line 199, in get_version
#     File "C:\ProgramData\Lucid Vision Labs\ArenaView\ArenaPy\Miniconda3\envs\lucid_env\lib\subprocess.py", line 411, in check_output
#       **kwargs).stdout
#     File "C:\ProgramData\Lucid Vision Labs\ArenaView\ArenaPy\Miniconda3\envs\lucid_env\lib\subprocess.py", line 488, in run
#       with Popen(*popenargs, **kwargs) as process:
#     File "C:\ProgramData\Lucid Vision Labs\ArenaView\ArenaPy\Miniconda3\envs\lucid_env\lib\subprocess.py", line 800, in __init__
#       restore_signals, start_new_session)
#     File "C:\ProgramData\Lucid Vision Labs\ArenaView\ArenaPy\Miniconda3\envs\lucid_env\lib\subprocess.py", line 1207, in _execute_child
#       startupinfo)
#   FileNotFoundError: [WinError 2] The system cannot find the file specified
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# Getting requirements to build wheel did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
#   Using cached dv_processing-1.7.9.tar.gz (9.5 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'

# %% [markdown]
# ## Accumulator

# %% [markdown]
# ### Accumulating event from a camera

# %%
from datetime import timedelta

import cv2 as cv
import dv_processing as dv

# Open any camera
capture = dv.io.camera.open()

# Make sure it supports event stream output, throw an error otherwise
if not capture.isEventStreamAvailable():
    raise RuntimeError("Input camera does not provide an event stream.")

# Initialize an accumulator with some resolution
accumulator = dv.Accumulator(capture.getEventResolution())

# Apply configuration, these values can be modified to taste
accumulator.setMinPotential(0.0)
accumulator.setMaxPotential(1.0)
accumulator.setNeutralPotential(0.5)
accumulator.setEventContribution(0.15)
accumulator.setDecayFunction(dv.Accumulator.Decay.EXPONENTIAL)
accumulator.setDecayParam(1e+6)
accumulator.setIgnorePolarity(False)
accumulator.setSynchronousDecay(False)

# Initialize preview window
cv.namedWindow("Preview", cv.WINDOW_NORMAL)

# Initialize a slicer
slicer = dv.EventStreamSlicer()


# Declare the callback method for slicer
def slicing_callback(events: dv.EventStore):
    # Pass events into the accumulator and generate a preview frame
    accumulator.accept(events)
    frame = accumulator.generateFrame()

    # Show the accumulated image
    cv.imshow("Preview", frame.image)
    cv.waitKey(2)


# Register a callback every 33 milliseconds
slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)

# Run the event processing while the camera is connected
while capture.isRunning():
    # Receive events
    events = capture.getNextEventBatch()

    # Check if anything was received
    if events is not None:
        # If so, pass the events into the slicer to handle them
        slicer.accept(events)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 48
#      45 slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)
#      47 # Run the event processing while the camera is connected
# ---> 48 while capture.isRunning():
#      49     # Receive events
#      50     events = capture.getNextEventBatch()
#      52     # Check if anything was received
#
# KeyboardInterrupt:

# %% [markdown]
# ### Edge accumulation

# %%
from datetime import timedelta

import cv2 as cv
import dv_processing as dv

# Open any camera
capture = dv.io.camera.open()

# Make sure it supports event stream output, throw an error otherwise
if not capture.isEventStreamAvailable():
    raise RuntimeError("Input camera does not provide an event stream.")

# Initialize an accumulator with some resolution
accumulator = dv.EdgeMapAccumulator(capture.getEventResolution())

# Apply configuration, these values can be modified to taste
accumulator.setNeutralPotential(0.0)
accumulator.setEventContribution(0.25)
accumulator.setNeutralPotential(1.0)
accumulator.setIgnorePolarity(True)

# Initialize a preview window
cv.namedWindow("Preview", cv.WINDOW_NORMAL)

# Initialize a slicer
slicer = dv.EventStreamSlicer()


# Declare the callback method for slicer
def slicing_callback(events: dv.EventStore):
    # Pass events into the accumulator and generate a preview frame
    accumulator.accept(events)
    frame = accumulator.generateFrame()

    # Show the accumulated image
    cv.imshow("Preview", frame.image)
    cv.waitKey(2)


# Register callback to be performed every 33 milliseconds
slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)

# Run the event processing while the camera is connected
while capture.isRunning():
    # Receive events
    events = capture.getNextEventBatch()

    # Check if anything was received
    if events is not None:
        # If so, pass the events into the slicer to handle them
        slicer.accept(events)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 44
#      41 slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)
#      43 # Run the event processing while the camera is connected
# ---> 44 while capture.isRunning():
#      45     # Receive events
#      46     events = capture.getNextEventBatch()
#      48     # Check if anything was received
#
# KeyboardInterrupt:

# %% [markdown]
# ### Time surface

# %%
from datetime import timedelta

import cv2 as cv
import dv_processing as dv

# Open any camera
capture = dv.io.camera.open()

# Make sure it supports event stream output, throw an error otherwise
if not capture.isEventStreamAvailable():
    raise RuntimeError("Input camera does not provide an event stream.")

# Initialize an accumulator with camera sensor resolution
surface = dv.TimeSurface(capture.getEventResolution())

# Initialize a preview window
cv.namedWindow("Preview", cv.WINDOW_NORMAL)

# Initialize a slicer
slicer = dv.EventStreamSlicer()


# Declare the callback method for slicer
def slicing_callback(events: dv.EventStore):
    # Pass the events to update the time surface
    surface.accept(events)

    # Generate a preview frame
    frame = surface.generateFrame()

    # Show the accumulated image
    cv.imshow("Preview", frame.image)
    cv.waitKey(2)


# Register callback to be performed every 33 milliseconds
slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)

# Run the event processing while the camera is connected
while capture.isRunning():
    # Receive events
    events = capture.getNextEventBatch()

    # Check if anything was received
    if events is not None:
        # If so, pass the events into the slicer to handle them
        slicer.accept(events)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 47
#      44 # Check if anything was received
#      45 if events is not None:
#      46     # If so, pass the events into the slicer to handle them
# ---> 47     slicer.accept(events)
#
# Cell In[8], line 33, in slicing_callback(events)
#      31 # Show the accumulated image
#      32 cv.imshow("Preview", frame.image)
# ---> 33 cv.waitKey(2)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Speed invariant time surface

# %%
from datetime import timedelta

import cv2 as cv
import dv_processing as dv

# Open any camera
capture = dv.io.camera.open()

# Make sure it supports event stream output, throw an error otherwise
if not capture.isEventStreamAvailable():
    raise RuntimeError("Input camera does not provide an event stream.")

# Initialize an accumulator with camera sensor resolution
surface = dv.SpeedInvariantTimeSurface(capture.getEventResolution())

# Initialize a preview window
cv.namedWindow("Preview", cv.WINDOW_NORMAL)

# Initialize a slicer
slicer = dv.EventStreamSlicer()


# Declare the callback method for slicer
def slicing_callback(events: dv.EventStore):
    # Pass the events to update the time surface
    surface.accept(events)

    # Generate a preview frame
    frame = surface.generateFrame()

    # Show the accumulated image
    cv.imshow("Preview", frame.image)
    cv.waitKey(2)


# Register callback to be performed every 33 milliseconds
slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)

# Run the event processing while the camera is connected
while capture.isRunning():
    # Receive events
    events = capture.getNextEventBatch()

    # Check if anything was received
    if events is not None:
        # If so, pass the events into the slicer to handle them
        slicer.accept(events)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 40
#      37 slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)
#      39 # Run the event processing while the camera is connected
# ---> 40 while capture.isRunning():
#      41     # Receive events
#      42     events = capture.getNextEventBatch()
#      44     # Check if anything was received
#
# KeyboardInterrupt:

# %% [markdown]
# ## Filtering events

# %%
import dv_processing as dv
import cv2 as cv
from datetime import timedelta

# Hardcoded VGA resolution
resolution = (640, 480)

# Initializing input events with uniformly distributed events which represent noise
events = dv.data.generate.uniformEventsWithinTimeRange(0, timedelta(milliseconds=10), resolution, 1000)

# Adding additional data for drawing, this will give an idea whether the filter removes actual signal events
events.add(dv.data.generate.dvLogoAsEvents(10000, resolution))

# Initialize a background activity noise filter with 1-millisecond activity period
filter = dv.noise.BackgroundActivityNoiseFilter(resolution, backgroundActivityDuration=timedelta(milliseconds=1))

# Pass events to the filter
filter.accept(events)

# Call generate events to apply the noise filter
filtered = filter.generateEvents()

# Print out the reduction factor, which indicates the percentage of discarded events
print(f"Filter reduced number of events by a factor of {filter.getReductionFactor()}")

# Use a visualizer instance to preview the events
visualizer = dv.visualization.EventVisualizer(resolution)

# Generate preview images of data input and output
input = visualizer.generateImage(events)
output = visualizer.generateImage(filtered)

# Concatenate the images into a single image for preview
preview = cv.hconcat([input, output])

# Display the input and output images
cv.namedWindow("preview", cv.WINDOW_NORMAL)
cv.imshow("preview", preview)
cv.waitKey()
# Out:
# Filter reduced number of events by a factor of 0.005161702632904053

# %% [markdown]
# ## Writing and Reading camera data

# %% [markdown]
# ### Writing event

# %%
import time
import dv_processing as dv

# --- Abrir la cámara ---
capture = dv.io.camera.open()

# Obtener la resolución de la cámara
resolution = capture.getEventResolution()

# Configuración para guardar solo eventos
config = dv.io.MonoCameraWriter.EventOnlyConfig("DAVIS346_sample", resolution)

# Crear el writer para escribir en archivo AEDAT4
writer = dv.io.MonoCameraWriter("output_davis346.aedat4", config)

print("Grabando eventos... Presiona Ctrl+C para detener.")

try:
    while capture.isRunning():
        # Leer siguiente lote de eventos
        events = capture.getNextEventBatch()

        if events is not None:
            # Guardar los eventos en el archivo
            writer.writeEvents(events)
        else:
            # Si no hay datos, dormir un poco para no sobrecargar la CPU
            time.sleep(0.001)

except KeyboardInterrupt:
    print("Grabación detenida.")

finally:
    # Cerrar cámara y escritor
    del writer
    del capture
    print("Archivo guardado como output_davis346.aedat4")
# Out:
# Grabando eventos... Presiona Ctrl+C para detener.
# Grabación detenida.
# Archivo guardado como output_davis346.aedat4

# %% [markdown]
# ### Read events from a file

# %%
from datetime import timedelta
import cv2 as cv
import dv_processing as dv

FILE_PATH = "C:/Users/gmarinhu/OneDrive - purdue.edu/Documents/code/output_davis346.aedat4" 

source = dv.io.MonoCameraRecording(FILE_PATH)

# Verificar que el stream de eventos está disponible
if not source.isEventStreamAvailable():
    raise RuntimeError("El archivo no contiene un stream de eventos.")

# Crear visualizador con la resolución correcta
visualizer = dv.visualization.EventVisualizer(source.getEventResolution())
visualizer.setBackgroundColor(dv.visualization.colors.white())
visualizer.setPositiveColor(dv.visualization.colors.iniBlue())
visualizer.setNegativeColor(dv.visualization.colors.darkGray())

# Ventana de visualización
cv.namedWindow("Eventos", cv.WINDOW_NORMAL)

# Crear slicer para agrupar eventos en intervalos de tiempo
slicer = dv.EventStreamSlicer()

# --- Callback para mostrar los eventos ---
def slicing_callback(events: dv.EventStore):
    frame = visualizer.generateImage(events)
    cv.imshow("Eventos", frame)
    if cv.waitKey(1) & 0xFF == ord('q'):
        # salir del loop principal
        global running
        running = False

# Registrar callback cada 33 ms (~30 FPS)
slicer.doEveryTimeInterval(timedelta(milliseconds=33), slicing_callback)

print("Mostrando eventos... (presiona 'q' para salir)")

# --- Loop principal ---
while source.isRunning():
    events = source.getNextEventBatch()
    if events is not None:
        slicer.accept(events)

# Cerrar
cv.destroyAllWindows()
del source
print("Finalizado.")
# Out:
# Mostrando eventos... (presiona 'q' para salir)
# Finalizado.

# %% [markdown]
# ### Read events with Tonic

# %%
import tonic

# Ruta a tu archivo .aedat4
FILE_PATH = "C:/Users/gmarinhu/OneDrive - purdue.edu/Documents/code/output_davis346.aedat4" 

# Cargar los eventos
events = tonic.io.read_aedat4(FILE_PATH)

print("Tipo:", type(events))
print("Campos:", events.dtype.names)
print("Número de eventos:", len(events))

# Ejemplo: acceder a los primeros 5 eventos
print(events[0])

print(type(events[0]["p"]))
# Out:
# Tipo: <class 'numpy.ndarray'>
# Campos: ('t', 'x', 'y', 'p')
# Número de eventos: 2191717
# (1758895097842180, 236, 218, False)
# <class 'numpy.bool_'>
